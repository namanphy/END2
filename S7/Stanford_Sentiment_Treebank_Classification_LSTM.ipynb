# %% [markdown]
# <a href="https://colab.research.google.com/github/namanphy/END2/blob/main/S5/Stanford_Sentiment_Treebank_Classification_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis - using LSTM
# Dataset : **Stanford Sentiment Treebank**
#
# Steps covered in this notebook:
# 1. Knowing the data

# %% [markdown]
# # Setting Up

# %%
# ! pip install pytreebank

# %%
# ! git clone https://github.com/namanphy/END2.git

# %%
# cd /content/END2/S5

# %%
# ! unzip /content/END2/S5/stanfordSentimentTreebank.zip

# %%
# ls

# %%
import os
import torch
import torchtext
from torchtext.legacy import data
import pandas as pd

from data import sentences_to_dataframe
from model import LSTM, BiLSTM, count_parameters
from trainer.loss import cross_entropy_loss
from trainer.optimizer import adam_optimizer
from trainer.train import train
from utils import binary_accuracy, plot_metric

# Manual Seed
SEED = 45
torch.manual_seed(SEED)

# %% [markdown]
# ---

# %% [markdown]
# # Preparing the data
#
# SST consists of 11,855 sentences extracted from movie reviews with fine-grained sentiment labels [1–5], as well as 215,154 phrases that compose each sentence in the dataset.

# %% [markdown]
# ## Generating train and test sentence-label dataframes
# From raw txt files..

# %%
df_train, df_test = sentences_to_dataframe(path_sst='/content/END2/S7/data/stanfordSentimentTreebank', seed=SEED)
# Out:
# Adding 940 more rows to trainset.
# /content/END2/S5/data/sst_dataset.py:29: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_train = pd.read_csv(out_path.format('train'), sep='\t\t', header=None, names=['label', 'text'])
# /content/END2/S5/data/sst_dataset.py:31: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   for f in ['test', 'dev']), ignore_index=True)

# %%
print(df_train.shape)
print(df_test.shape)
df_train.head(2)
# Out:
# (9484, 2)
# (2371, 3)
#    label                                               text
# 0      4  The Rock is destined to be the 21st Century 's...
# 1      5  The gorgeously elaborate continuation of `` Th...

# %% [markdown]
# ## Adding Augmented files to training data

# %% [markdown]
# ## Knowing our Data

# %% [markdown]
# Our dataset is ofcourse not balanced. It is clear that most of the training samples belong to classes 2 and 4. Also a good number of samples belong to `neutral` class i.e. label 3.

# %%
import matplotlib.pyplot as plt

ax = df_train['label'].value_counts(sort=False).plot(kind='bar')
ax.set_xlabel("Labels")
ax.set_ylabel("Number of Samples in training Set")
# Out:
# Text(0, 0.5, 'Number of Samples in training Set')

# %% [markdown]
# What's the distribution of the lengths of the data ?
#
# **It has a average of 102 in the training set.**

# %%
reviews_len = [len(x) for x in df_train['text']]
ax = pd.Series(reviews_len).hist()
ax.set_xlabel("Length of examples in training set")
ax.set_ylabel("Number of Samples in training Set")
pd.Series(reviews_len).describe()
# Out:
# count    14700.000000
# mean        94.199320
# std         53.310125
# min          1.000000
# 25%         53.000000
# 50%         90.000000
# 75%        130.000000
# max        267.000000
# dtype: float64

# %%
min(reviews_len)
# Out:
# 1

# %% [markdown]
# ## Making a torchtext dataset and dataloader

# %%
text = data.Field(sequential=True, tokenize='spacy', batch_first =True, include_lengths=True)
label = data.LabelField(sequential=False, tokenize ='spacy',  batch_first=True, is_target=True)

# %%
fields = [('texts', text), ('labels', label)]

# %%
# Generated Examples from the train and test data

train_example = [data.Example.fromlist([df_train.text[i], df_train.label[i]], fields) for i in range(df_train.shape[0])]
test_example = [data.Example.fromlist([df_test.text[i], df_test.label[i]], fields) for i in range(df_test.shape[0])]

# %% [markdown]
# #### Building Dataset

# %%
train_dataset = data.Dataset(train_example, fields)
test_dataset = data.Dataset(test_example, fields)

# %%
print('Length of training dataset: ', len(train_dataset))
print('Length of testing dataset: ', len(test_dataset))
# Out:
# Length of training dataset:  14700
# Length of testing dataset:  2371

# %% [markdown]
# #### Building Vocab

# %%
text.build_vocab(train_dataset)
label.build_vocab(train_dataset)

# %%
print('Size of input vocab : ', len(text.vocab))
print('Size of label vocab : ', len(label.vocab))
print('Top 10 words appreared repeatedly :', list(text.vocab.freqs.most_common(10)))
print('Labels : ', label.vocab.stoi)
# Out:
# Size of input vocab :  18783
# Size of label vocab :  5
# Top 10 words appreared repeatedly : [('.', 14205), (',', 12298), ('the', 9659), ('and', 7043), ('a', 6964), ('of', 6917), ('-', 5269), ('to', 4794), ('is', 3934), ("'", 3132)]
# Labels :  defaultdict(None, {4: 0, 2: 1, 3: 2, 5: 3, 1: 4})

# %% [markdown]
# **Lots of stopwords!! YES INDEED!!**

# %% [markdown]
# #### Making a data iterator

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_iterator, test_iterator = data.BucketIterator.splits((train_dataset, test_dataset), 
                                                           batch_size=64, 
                                                           sort_key=lambda x: len(x.texts),
                                                           sort_within_batch=True,
                                                           device=device)

# %% [markdown]
# **Notice that i haven't used padding for my sentences(data) here.**

# %%
print('Train')
for batch in train_iterator:
    print(f'Text size: {batch.texts[0].size()}')
    print(f'Label size: {batch.labels.size()}')
    break

print('\nTest:')
for batch in test_iterator:
    print(f'Text size: {batch.texts[0].size()}')
    print(f'Label size: {batch.labels.size()}')
    break
# Out:
# Train
# Text size: torch.Size([64, 10])
# Label size: torch.Size([64])
#
# Test:
# Text size: torch.Size([64, 5])
# Label size: torch.Size([64])

# %%
import pickle
with open('tokenizer.pkl', 'wb') as tokens: 
    pickle.dump(text.vocab.stoi, tokens)

# %% [markdown]
# # Model Preparation

# %%
# Hyperparams

size_of_vocab = len(text.vocab)
embedding_dim = 200
num_hidden_nodes = 128
num_output_nodes = 5
num_layers = 1
dropout = 0.4

model = BiLSTM(size_of_vocab, embedding_dim, num_hidden_nodes, num_output_nodes, num_layers, dropout)  # TODO: BiLSTM
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:63: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
print(model)
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# LSTM(
#   (embedding): Embedding(18783, 200)
#   (lstm): LSTM(200, 128, dropout=0.4, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=5, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# The model has 4,095,805 trainable parameters

# %% [markdown]
# # Training

# %%
optimizer = adam_optimizer(model, lr=0.0001)  # TODO: lr=0.001
criterion = cross_entropy_loss()

model = model.to(device)
# criterion = criterion.to(device)

# %%
train_losses, test_losses, train_accuracies, test_accuracies = train(model, 
                                                                     train_iterator, 
                                                                     test_iterator, 
                                                                     optimizer, 
                                                                     criterion,
                                                                     binary_accuracy,
                                                                     epochs=100)
# Out:
# True
# Epoch: 01 | Epoch Time: 0m 2s
# 	Train Loss: 1.589 | Train Acc: 25.91%
# 	 Val. Loss: 1.575 |  Val. Acc: 28.02%
#
# Epoch: 02 | Epoch Time: 0m 2s
# 	Train Loss: 1.577 | Train Acc: 27.13%
# 	 Val. Loss: 1.576 |  Val. Acc: 25.40%
#
# Epoch: 03 | Epoch Time: 0m 2s
# 	Train Loss: 1.574 | Train Acc: 28.00%
# 	 Val. Loss: 1.574 |  Val. Acc: 25.40%
#
# Epoch: 04 | Epoch Time: 0m 2s
# 	Train Loss: 1.571 | Train Acc: 29.04%
# 	 Val. Loss: 1.570 |  Val. Acc: 29.00%
#
# Epoch: 05 | Epoch Time: 0m 2s
# 	Train Loss: 1.569 | Train Acc: 29.70%
# 	 Val. Loss: 1.568 |  Val. Acc: 29.45%
#
# Epoch: 06 | Epoch Time: 0m 2s
# 	Train Loss: 1.564 | Train Acc: 30.66%
# 	 Val. Loss: 1.565 |  Val. Acc: 30.28%
#
# Epoch: 07 | Epoch Time: 0m 2s
# 	Train Loss: 1.558 | Train Acc: 31.90%
# 	 Val. Loss: 1.562 |  Val. Acc: 31.52%
#
# Epoch: 08 | Epoch Time: 0m 2s
# 	Train Loss: 1.551 | Train Acc: 32.60%
# 	 Val. Loss: 1.544 |  Val. Acc: 33.76%
#
# Epoch: 09 | Epoch Time: 0m 2s
# 	Train Loss: 1.540 | Train Acc: 34.75%
# 	 Val. Loss: 1.546 |  Val. Acc: 33.63%
#
# Epoch: 10 | Epoch Time: 0m 2s
# 	Train Loss: 1.533 | Train Acc: 35.43%
# 	 Val. Loss: 1.539 |  Val. Acc: 34.70%
#
# Epoch: 11 | Epoch Time: 0m 2s
# 	Train Loss: 1.523 | Train Acc: 36.46%
# 	 Val. Loss: 1.541 |  Val. Acc: 35.16%
#
# Epoch: 12 | Epoch Time: 0m 2s
# 	Train Loss: 1.520 | Train Acc: 36.80%
# 	 Val. Loss: 1.535 |  Val. Acc: 35.28%
#
# Epoch: 13 | Epoch Time: 0m 2s
# 	Train Loss: 1.511 | Train Acc: 38.03%
# 	 Val. Loss: 1.537 |  Val. Acc: 35.07%
#
# Epoch: 14 | Epoch Time: 0m 2s
# 	Train Loss: 1.506 | Train Acc: 38.33%
# 	 Val. Loss: 1.529 |  Val. Acc: 36.10%
#
# Epoch: 15 | Epoch Time: 0m 2s
# 	Train Loss: 1.498 | Train Acc: 39.23%
# 	 Val. Loss: 1.532 |  Val. Acc: 35.81%
#
# Epoch: 16 | Epoch Time: 0m 2s
# 	Train Loss: 1.492 | Train Acc: 40.08%
# 	 Val. Loss: 1.527 |  Val. Acc: 36.31%
#
# Epoch: 17 | Epoch Time: 0m 2s
# 	Train Loss: 1.486 | Train Acc: 40.62%
# 	 Val. Loss: 1.538 |  Val. Acc: 35.22%
#
# Epoch: 18 | Epoch Time: 0m 2s
# 	Train Loss: 1.482 | Train Acc: 40.94%
# 	 Val. Loss: 1.536 |  Val. Acc: 35.47%
#
# Epoch: 19 | Epoch Time: 0m 2s
# 	Train Loss: 1.478 | Train Acc: 41.25%
# 	 Val. Loss: 1.523 |  Val. Acc: 36.68%
#
# Epoch: 20 | Epoch Time: 0m 2s
# 	Train Loss: 1.472 | Train Acc: 42.03%
# 	 Val. Loss: 1.523 |  Val. Acc: 36.60%
#
# Epoch: 21 | Epoch Time: 0m 2s
# 	Train Loss: 1.466 | Train Acc: 42.40%
# 	 Val. Loss: 1.520 |  Val. Acc: 36.84%
#
# Epoch: 22 | Epoch Time: 0m 2s
# 	Train Loss: 1.462 | Train Acc: 43.17%
# 	 Val. Loss: 1.520 |  Val. Acc: 36.88%
#
# Epoch: 23 | Epoch Time: 0m 2s
# 	Train Loss: 1.457 | Train Acc: 43.63%
# 	 Val. Loss: 1.518 |  Val. Acc: 37.29%
#
# Epoch: 24 | Epoch Time: 0m 2s
# 	Train Loss: 1.452 | Train Acc: 44.10%
# 	 Val. Loss: 1.517 |  Val. Acc: 37.38%
#
# Epoch: 25 | Epoch Time: 0m 2s
# 	Train Loss: 1.450 | Train Acc: 44.42%
# 	 Val. Loss: 1.517 |  Val. Acc: 37.25%
#
# Epoch: 26 | Epoch Time: 0m 2s
# 	Train Loss: 1.448 | Train Acc: 44.66%
# 	 Val. Loss: 1.514 |  Val. Acc: 37.75%
#
# Epoch: 27 | Epoch Time: 0m 2s
# 	Train Loss: 1.441 | Train Acc: 45.22%
# 	 Val. Loss: 1.513 |  Val. Acc: 38.03%
#
# Epoch: 28 | Epoch Time: 0m 2s
# 	Train Loss: 1.439 | Train Acc: 45.27%
# 	 Val. Loss: 1.512 |  Val. Acc: 38.12%
#
# Epoch: 29 | Epoch Time: 0m 2s
# 	Train Loss: 1.435 | Train Acc: 45.92%
# 	 Val. Loss: 1.509 |  Val. Acc: 38.32%
#
# Epoch: 30 | Epoch Time: 0m 2s
# 	Train Loss: 1.431 | Train Acc: 46.47%
# 	 Val. Loss: 1.507 |  Val. Acc: 38.61%
#
# Epoch: 31 | Epoch Time: 0m 2s
# 	Train Loss: 1.428 | Train Acc: 46.48%
# 	 Val. Loss: 1.508 |  Val. Acc: 38.28%
#
# Epoch: 32 | Epoch Time: 0m 2s
# 	Train Loss: 1.423 | Train Acc: 47.06%
# 	 Val. Loss: 1.509 |  Val. Acc: 38.28%
#
# Epoch: 33 | Epoch Time: 0m 2s
# 	Train Loss: 1.424 | Train Acc: 46.90%
# 	 Val. Loss: 1.508 |  Val. Acc: 38.32%
#
# Epoch: 34 | Epoch Time: 0m 2s
# 	Train Loss: 1.420 | Train Acc: 47.43%
# 	 Val. Loss: 1.506 |  Val. Acc: 38.45%
#
# Epoch: 35 | Epoch Time: 0m 2s
# 	Train Loss: 1.414 | Train Acc: 48.12%
# 	 Val. Loss: 1.507 |  Val. Acc: 38.69%
#
# Epoch: 36 | Epoch Time: 0m 2s
# 	Train Loss: 1.415 | Train Acc: 48.07%
# 	 Val. Loss: 1.509 |  Val. Acc: 38.32%
#
# Epoch: 37 | Epoch Time: 0m 2s
# 	Train Loss: 1.409 | Train Acc: 48.39%
# 	 Val. Loss: 1.507 |  Val. Acc: 38.69%
#
# Epoch: 38 | Epoch Time: 0m 2s
# 	Train Loss: 1.408 | Train Acc: 48.97%
# 	 Val. Loss: 1.512 |  Val. Acc: 37.94%
#
# Epoch: 39 | Epoch Time: 0m 2s
# 	Train Loss: 1.403 | Train Acc: 49.22%
# 	 Val. Loss: 1.502 |  Val. Acc: 39.27%
#
# Epoch: 40 | Epoch Time: 0m 2s
# 	Train Loss: 1.402 | Train Acc: 49.22%
# 	 Val. Loss: 1.504 |  Val. Acc: 38.86%
#
# Epoch: 41 | Epoch Time: 0m 2s
# 	Train Loss: 1.398 | Train Acc: 49.74%
# 	 Val. Loss: 1.505 |  Val. Acc: 38.90%
#
# Epoch: 42 | Epoch Time: 0m 2s
# 	Train Loss: 1.397 | Train Acc: 50.06%
# 	 Val. Loss: 1.506 |  Val. Acc: 38.69%
#
# Epoch: 43 | Epoch Time: 0m 2s
# 	Train Loss: 1.393 | Train Acc: 50.35%
# 	 Val. Loss: 1.508 |  Val. Acc: 38.82%
#
# Epoch: 44 | Epoch Time: 0m 2s
# 	Train Loss: 1.389 | Train Acc: 50.71%
# 	 Val. Loss: 1.502 |  Val. Acc: 39.35%
#
# Epoch: 45 | Epoch Time: 0m 2s
# 	Train Loss: 1.388 | Train Acc: 50.91%
# 	 Val. Loss: 1.505 |  Val. Acc: 38.82%
#
# Epoch: 46 | Epoch Time: 0m 2s
# 	Train Loss: 1.383 | Train Acc: 51.60%
# 	 Val. Loss: 1.501 |  Val. Acc: 39.23%
#
# Epoch: 47 | Epoch Time: 0m 2s
# 	Train Loss: 1.382 | Train Acc: 51.38%
# 	 Val. Loss: 1.508 |  Val. Acc: 38.65%
#
# Epoch: 48 | Epoch Time: 0m 2s
# 	Train Loss: 1.379 | Train Acc: 51.80%
# 	 Val. Loss: 1.502 |  Val. Acc: 39.47%
#
# Epoch: 49 | Epoch Time: 0m 2s
# 	Train Loss: 1.376 | Train Acc: 52.38%
# 	 Val. Loss: 1.497 |  Val. Acc: 39.76%
#
# Epoch: 50 | Epoch Time: 0m 2s
# 	Train Loss: 1.374 | Train Acc: 52.53%
# 	 Val. Loss: 1.495 |  Val. Acc: 39.88%
#
# Epoch: 51 | Epoch Time: 0m 2s
# 	Train Loss: 1.375 | Train Acc: 52.15%
# 	 Val. Loss: 1.501 |  Val. Acc: 39.43%
#
# Epoch: 52 | Epoch Time: 0m 2s
# 	Train Loss: 1.369 | Train Acc: 53.27%
# 	 Val. Loss: 1.501 |  Val. Acc: 39.47%
#
# Epoch: 53 | Epoch Time: 0m 2s
# 	Train Loss: 1.367 | Train Acc: 52.90%
# 	 Val. Loss: 1.501 |  Val. Acc: 39.43%
#
# Epoch: 54 | Epoch Time: 0m 2s
# 	Train Loss: 1.367 | Train Acc: 53.04%
# 	 Val. Loss: 1.497 |  Val. Acc: 40.25%
#
# Epoch: 55 | Epoch Time: 0m 2s
# 	Train Loss: 1.366 | Train Acc: 53.20%
# 	 Val. Loss: 1.505 |  Val. Acc: 39.14%
#
# Epoch: 56 | Epoch Time: 0m 2s
# 	Train Loss: 1.359 | Train Acc: 54.13%
# 	 Val. Loss: 1.505 |  Val. Acc: 38.73%
#
# Epoch: 57 | Epoch Time: 0m 2s
# 	Train Loss: 1.359 | Train Acc: 53.99%
# 	 Val. Loss: 1.501 |  Val. Acc: 39.31%
#
# Epoch: 58 | Epoch Time: 0m 2s
# 	Train Loss: 1.357 | Train Acc: 54.24%
# 	 Val. Loss: 1.497 |  Val. Acc: 39.72%
#
# Epoch: 59 | Epoch Time: 0m 2s
# 	Train Loss: 1.354 | Train Acc: 54.80%
# 	 Val. Loss: 1.500 |  Val. Acc: 38.94%
#
# Epoch: 60 | Epoch Time: 0m 2s
# 	Train Loss: 1.350 | Train Acc: 54.87%
# 	 Val. Loss: 1.497 |  Val. Acc: 39.80%
#
# Epoch: 61 | Epoch Time: 0m 2s
# 	Train Loss: 1.351 | Train Acc: 54.68%
# 	 Val. Loss: 1.500 |  Val. Acc: 39.43%
#
# Epoch: 62 | Epoch Time: 0m 2s
# 	Train Loss: 1.347 | Train Acc: 55.39%
# 	 Val. Loss: 1.502 |  Val. Acc: 39.06%
#
# Epoch: 63 | Epoch Time: 0m 2s
# 	Train Loss: 1.343 | Train Acc: 55.82%
# 	 Val. Loss: 1.499 |  Val. Acc: 39.51%
#
# Epoch: 64 | Epoch Time: 0m 2s
# 	Train Loss: 1.337 | Train Acc: 56.19%
# 	 Val. Loss: 1.500 |  Val. Acc: 39.47%
#
# Epoch: 65 | Epoch Time: 0m 2s
# 	Train Loss: 1.335 | Train Acc: 56.54%
# 	 Val. Loss: 1.505 |  Val. Acc: 38.64%
#
# Epoch: 66 | Epoch Time: 0m 2s
# 	Train Loss: 1.334 | Train Acc: 56.46%
# 	 Val. Loss: 1.504 |  Val. Acc: 38.88%
#
# Epoch: 67 | Epoch Time: 0m 2s
# 	Train Loss: 1.330 | Train Acc: 57.17%
# 	 Val. Loss: 1.506 |  Val. Acc: 39.01%
#
# Epoch: 68 | Epoch Time: 0m 2s
# 	Train Loss: 1.333 | Train Acc: 56.73%
# 	 Val. Loss: 1.501 |  Val. Acc: 39.05%
#
# Epoch: 69 | Epoch Time: 0m 2s
# 	Train Loss: 1.331 | Train Acc: 56.95%
# 	 Val. Loss: 1.506 |  Val. Acc: 38.68%
#
# Epoch: 70 | Epoch Time: 0m 2s
# 	Train Loss: 1.330 | Train Acc: 57.12%
# 	 Val. Loss: 1.499 |  Val. Acc: 39.68%
#
# Epoch: 71 | Epoch Time: 0m 2s
# 	Train Loss: 1.324 | Train Acc: 57.76%
# 	 Val. Loss: 1.499 |  Val. Acc: 39.68%
#
# Epoch: 72 | Epoch Time: 0m 2s
# 	Train Loss: 1.322 | Train Acc: 57.95%
# 	 Val. Loss: 1.508 |  Val. Acc: 38.23%
#
# Epoch: 73 | Epoch Time: 0m 2s
# 	Train Loss: 1.322 | Train Acc: 57.99%
# 	 Val. Loss: 1.497 |  Val. Acc: 39.56%
#
# Epoch: 74 | Epoch Time: 0m 2s
# 	Train Loss: 1.320 | Train Acc: 58.05%
# 	 Val. Loss: 1.495 |  Val. Acc: 39.72%
#
# Epoch: 75 | Epoch Time: 0m 2s
# 	Train Loss: 1.315 | Train Acc: 58.72%
# 	 Val. Loss: 1.491 |  Val. Acc: 40.46%
#
# Epoch: 76 | Epoch Time: 0m 2s
# 	Train Loss: 1.315 | Train Acc: 58.58%
# 	 Val. Loss: 1.496 |  Val. Acc: 40.17%
#
# Epoch: 77 | Epoch Time: 0m 2s
# 	Train Loss: 1.309 | Train Acc: 59.50%
# 	 Val. Loss: 1.495 |  Val. Acc: 40.25%
#
# Epoch: 78 | Epoch Time: 0m 2s
# 	Train Loss: 1.310 | Train Acc: 59.13%
# 	 Val. Loss: 1.498 |  Val. Acc: 39.64%
#
# Epoch: 79 | Epoch Time: 0m 2s
# 	Train Loss: 1.312 | Train Acc: 58.81%
# 	 Val. Loss: 1.492 |  Val. Acc: 40.54%
#
# Epoch: 80 | Epoch Time: 0m 2s
# 	Train Loss: 1.302 | Train Acc: 60.04%
# 	 Val. Loss: 1.493 |  Val. Acc: 39.97%
#
# Epoch: 81 | Epoch Time: 0m 2s
# 	Train Loss: 1.304 | Train Acc: 59.81%
# 	 Val. Loss: 1.496 |  Val. Acc: 39.76%
#
# Epoch: 82 | Epoch Time: 0m 2s
# 	Train Loss: 1.300 | Train Acc: 60.32%
# 	 Val. Loss: 1.496 |  Val. Acc: 39.72%
#
# Epoch: 83 | Epoch Time: 0m 2s
# 	Train Loss: 1.301 | Train Acc: 60.03%
# 	 Val. Loss: 1.499 |  Val. Acc: 39.64%
#
# Epoch: 84 | Epoch Time: 0m 2s
# 	Train Loss: 1.299 | Train Acc: 60.22%
# 	 Val. Loss: 1.493 |  Val. Acc: 39.84%
#
# Epoch: 85 | Epoch Time: 0m 2s
# 	Train Loss: 1.293 | Train Acc: 60.94%
# 	 Val. Loss: 1.492 |  Val. Acc: 40.34%
#
# Epoch: 86 | Epoch Time: 0m 2s
# 	Train Loss: 1.291 | Train Acc: 61.29%
# 	 Val. Loss: 1.488 |  Val. Acc: 40.58%
#
# Epoch: 87 | Epoch Time: 0m 2s
# 	Train Loss: 1.293 | Train Acc: 60.66%
# 	 Val. Loss: 1.500 |  Val. Acc: 39.47%
#
# Epoch: 88 | Epoch Time: 0m 2s
# 	Train Loss: 1.287 | Train Acc: 61.52%
# 	 Val. Loss: 1.495 |  Val. Acc: 40.01%
#
# Epoch: 89 | Epoch Time: 0m 2s
# 	Train Loss: 1.289 | Train Acc: 61.30%
# 	 Val. Loss: 1.502 |  Val. Acc: 39.21%
#
# Epoch: 90 | Epoch Time: 0m 2s
# 	Train Loss: 1.288 | Train Acc: 61.43%
# 	 Val. Loss: 1.494 |  Val. Acc: 40.34%
#
# Epoch: 91 | Epoch Time: 0m 2s
# 	Train Loss: 1.286 | Train Acc: 61.36%
# 	 Val. Loss: 1.496 |  Val. Acc: 39.93%
#
# Epoch: 92 | Epoch Time: 0m 2s
# 	Train Loss: 1.285 | Train Acc: 61.55%
# 	 Val. Loss: 1.495 |  Val. Acc: 40.21%
#
# Epoch: 93 | Epoch Time: 0m 2s
# 	Train Loss: 1.280 | Train Acc: 62.40%
# 	 Val. Loss: 1.502 |  Val. Acc: 39.34%
#
# Epoch: 94 | Epoch Time: 0m 2s
# 	Train Loss: 1.278 | Train Acc: 62.48%
# 	 Val. Loss: 1.492 |  Val. Acc: 40.05%
#
# Epoch: 95 | Epoch Time: 0m 2s
# 	Train Loss: 1.275 | Train Acc: 62.73%
# 	 Val. Loss: 1.502 |  Val. Acc: 38.97%
#
# Epoch: 96 | Epoch Time: 0m 2s
# 	Train Loss: 1.275 | Train Acc: 62.85%
# 	 Val. Loss: 1.502 |  Val. Acc: 39.01%
#
# Epoch: 97 | Epoch Time: 0m 2s
# 	Train Loss: 1.273 | Train Acc: 62.93%
# 	 Val. Loss: 1.497 |  Val. Acc: 39.71%
#
# Epoch: 98 | Epoch Time: 0m 2s
# 	Train Loss: 1.270 | Train Acc: 63.16%
# 	 Val. Loss: 1.497 |  Val. Acc: 39.72%
#
# Epoch: 99 | Epoch Time: 0m 2s
# 	Train Loss: 1.270 | Train Acc: 63.15%
# 	 Val. Loss: 1.493 |  Val. Acc: 40.21%
#
# Epoch: 100 | Epoch Time: 0m 2s
# 	Train Loss: 1.271 | Train Acc: 62.96%
# 	 Val. Loss: 1.504 |  Val. Acc: 38.71%

# %% [markdown]
# # Evaluation

# %%
plot_metric([train_losses, test_losses], ['train', 'test'], 'Epoch', 'Loss', 'Loss')
print('\n')
plot_metric([train_accuracies, test_accuracies], ['train', 'test'], 'Epoch', 'Accuracy', 'Accuracy')

# %% [markdown]
# ## Finding misclassified texts

# %%
categories = {0: "Big Negative", 1:"Negative", 2:"Neutral", 3:"Positive", 4:"Big Positive"}

j = 0
for batch in test_iterator:
    # pred = classify_tweet('I am very negative negative negaive')

    pred_label = batch.labels
    pred_texts, pred_text_lengths = batch.texts
    pred_text, pred_text_length = pred_texts[0], pred_text_lengths[0]
    # print(pred_text, pred_text_length)

    # Get the model prediction                  
    prediction = model(pred_text.unsqueeze(0), pred_text_length.unsqueeze(0))
    _, pred = torch.max(prediction, 1) 

    print('Sentence : ', ' '.join([text.vocab.itos[x] for x in list(pred_text)]))
    print('\tPredicted Label : ', categories[pred.item()])
    print('\tCorrect Label   : ', categories[pred_label[0].item()])
    
    if j > 12:
        break
# Out:
# Sentence :  <unk> motions for <unk> .
# 	Predicted Label :  Negative
# 	Correct Label   :  Neutral
# Sentence :  Something like <unk> the toilet .
# 	Predicted Label :  Negative
# 	Correct Label   :  Negative
# Sentence :  Morton is , as usual , brilliant .
# 	Predicted Label :  Positive
# 	Correct Label   :  Positive
# Sentence :  A painfully funny ode to bad behavior .
# 	Predicted Label :  Negative
# 	Correct Label   :  Big Negative
# Sentence :  A poignant , artfully crafted meditation on mortality .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Positive
# Sentence :  <unk> substitutes atmosphere for action , tedium for thrills .
# 	Predicted Label :  Negative
# 	Correct Label   :  Negative
# Sentence :  But this time there 's some mold on the gold .
# 	Predicted Label :  Neutral
# 	Correct Label   :  Negative
# Sentence :  A deviant topical comedy which is funny from start to finish .
# 	Predicted Label :  Neutral
# 	Correct Label   :  Positive
# Sentence :  <unk> dramas fused with love triangle is a well worn conceit .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Neutral
# Sentence :  The best film about baseball to hit theaters since <unk> of Dreams .
# 	Predicted Label :  Positive
# 	Correct Label   :  Positive
# Sentence :  But here 's the real damn : It is n't funny , either .
# 	Predicted Label :  Negative
# 	Correct Label   :  Big Positive
# Sentence :  A psychologically rich and suspenseful moral thriller with a stellar performance by <unk> Pacino .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Negative
# Sentence :  The kind of spectacularly misconceived enterprise that only a sophisticated cinephile could have perpetrated .
# 	Predicted Label :  Negative
# 	Correct Label   :  Neutral
# Sentence :  Rather quickly , the film falls into a soothing formula of <unk> conflict and reconciliation .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Negative
# Sentence :  ... has freaky scenes where the crew wonder if they 're ghosts imagining themselves as alive .
# 	Predicted Label :  Neutral
# 	Correct Label   :  Neutral
# Sentence :  If only the story about a multi - million dollar con bothered to include the con .
# 	Predicted Label :  Neutral
# 	Correct Label   :  Neutral
# Sentence :  Blessed with immense physical prowess he may well be , but Ahola is simply not an actor .
# 	Predicted Label :  Negative
# 	Correct Label   :  Negative
# Sentence :  Biggie and Tupac is so single - <unk> daring , it puts far more polished documentaries to shame .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Positive
# Sentence :  A sports movie with action that 's exciting on the field and a story you care about off it .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Positive
# Sentence :  Feature <unk> D.J. Caruso directs a crack ensemble cast , bringing screenwriter Tony Gayton 's <unk> noir to life .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Positive
# Sentence :  This film , starring Anthony Hopkins and Chris Rock , is your typical ` fish out of water ' story .
# 	Predicted Label :  Negative
# 	Correct Label   :  Neutral
# Sentence :  The experience of watching <unk> old - school CGI animation in this <unk> format is just surreal enough to be diverting .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Negative
# Sentence :  Full of witless jokes , dealing in broad stereotypes and outrageously unbelievable scenarios , and saddled with a general air of misogyny
# 	Predicted Label :  Negative
# 	Correct Label   :  Neutral
# Sentence :  <unk> and unfunny , Adam Sandler 's cartoon about Hanukkah is numbingly bad , Little Nicky bad , 10 <unk> List bad .
# 	Predicted Label :  Negative
# 	Correct Label   :  Big Positive
# Sentence :  It 's a minor comedy that tries to balance sweetness with <unk> , while it paints a sad picture of the singles scene .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Negative
# Sentence :  <unk> sweet sentimentality , clumsy plotting and a <unk> myopic view of life in the WWII - era <unk> <unk> undermine this adaptation .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Positive
# Sentence :  His comedy <unk> are often hackneyed or just plain crude , calculated to provoke shocked laughter , without following up on a deeper level .
# 	Predicted Label :  Negative
# 	Correct Label   :  Negative
# Sentence :  It 's of the quality of a lesser Harrison Ford movie - <unk> Days , Seven Nights , maybe , or that dreadful <unk> remake .
# 	Predicted Label :  Negative
# 	Correct Label   :  Negative
# Sentence :  The Movie could have been made 40 years ago , and parents ' appreciation of it may depend on whether they consider that a good thing .
# 	Predicted Label :  Negative
# 	Correct Label   :  Neutral
# Sentence :  You will emerge with a <unk> view of how the gears of justice grind on and the death report comes to share <unk> alongside the farm report .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Negative
# Sentence :  All - in - all , the film is an enjoyable and frankly told tale of a people who live among us , but not necessarily with us .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Negative
# Sentence :  If there 's a way to effectively teach kids about the dangers of drugs , I think it 's in projects like the ( unfortunately R - rated ) Paid .
# 	Predicted Label :  Negative
# 	Correct Label   :  Big Negative
# Sentence :  Like so many other allegedly scary movies , it gets so tangled up in The Twist that it chokes the energy right out of the very audience it seeks to frighten .
# 	Predicted Label :  Neutral
# 	Correct Label   :  Big Positive
# Sentence :  Evokes a little of the fear that parents have for the possible <unk> of their children -- and the sometimes bad choices mothers and fathers make in the interests of doing them good .
# 	Predicted Label :  Big Negative
# 	Correct Label   :  Big Negative
# Sentence :  It 's drained of life in an attempt to be sober and educational , and yet it 's so devoid of realism that its lack of <unk> and <unk> just makes it obnoxious and stiff .
# 	Predicted Label :  Negative
# 	Correct Label   :  Big Positive
# Sentence :  The twist that ends the movie is the one with the most emotional resonance , but twists are getting irritating , and this is the kind of material where the filmmakers should be very careful about raising <unk> .
# 	Predicted Label :  Negative
# 	Correct Label   :  Neutral
# Sentence :  Its scenes and sensibility are all more than familiar , but it exudes a kind of nostalgic spy - movie charm and , at the same time , is so fresh and free of the usual thriller nonsense that it all seems to be happening for the first time .
# 	Predicted Label :  Negative
# 	Correct Label   :  Big Negative
# Sentence :  The film is faithful to what one presumes are the book 's twin <unk> -- that we become who we are on the <unk> of our parents , but we have no idea who they were at our age ; and that time is a fleeting and precious <unk> no matter how old you are .
# 	Predicted Label :  Negative
# 	Correct Label   :  Big Negative

# %%
# #load weights and tokenizer

# path='/content/END2/weights/best_model.pt'
# model.load_state_dict(torch.load(path));
# model.eval();
# tokenizer_file = open('/content/END2/S5/tokenizer.pkl', 'rb')
# tokenizer = pickle.load(tokenizer_file)

# #inference

# import spacy
# nlp = spacy.load('en')

# def classify_tweet(text):
#     categories = {0: "Big Negative", 1:"Negative", 2:"Neutral", 3:"Positive", 4:"Big Positive"}
    
#     tokenized = [tok.text for tok in nlp.tokenizer(text)] 

#     # convert to integer sequence using predefined tokenizer dictionary
#     indexed = [tokenizer[t] for t in tokenized]               
#     length = [len(indexed)]

#     # convert sentence to tensor                                    
#     tensor = torch.LongTensor(indexed).to(device)
#     # reshape in form of batch, no. of words           
#     tensor = tensor.unsqueeze(1).T
 
#     # convert length to tensor                          
#     length_tensor = torch.LongTensor(length)

#     # Get the model prediction                  
#     prediction = model(tensor, length_tensor)

#     _, pred = torch.max(prediction, 1) 
    
#     return categories[pred.item()]

# %% [markdown]
# # ----

# %% [markdown]
# -------
# -------

# %% [markdown]
# # Data Augmentations - Doing Random Swap and Random Delete

# %%
! pip install nlpaug

# %%
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas

# %%
random_swap = naw.RandomWordAug(action="swap", aug_p=20, aug_min=2, aug_max=10)
random_delete = naw.RandomWordAug(action="delete", aug_p=20, aug_min=2, aug_max=10)

# %%
df_sample1 = df_train.sample(int(df_train.shape[0]/4))
df_sample2 = df_train.sample(int(df_train.shape[0]/4))

# %%
print(df_sample1.shape), print(df_sample2.shape)
# Out:
# (2371, 2)
# (2371, 2)
# (None, None)

# %%
aug_data_swap = {'label': [], 'text': []}
aug_data_delete = {'label': [], 'text': []}

for ix, (label_field, text_field) in df_sample1.iterrows():
    aug_data_swap['text'].append(random_swap.augment(text_field))
    aug_data_swap['label'].append(label_field)

for ix, (label_field, text_field) in df_sample2.iterrows():
    # print(text_field)
    # print(label_field)
    aug_data_delete['text'].append(random_delete.augment(text_field))
    aug_data_delete['label'].append(label_field)

# %%
assert len(aug_data_swap['label']) == len(aug_data_swap['text']), "Some error occured. Size Mismatch!"
print(len(aug_data_swap['text']))

assert len(aug_data_delete['label']) == len(aug_data_delete['text']), "Some error occured. Size Mismatch!"
len(aug_data_delete['text'])
# Out:
# 2371
# 2371

# %%
df_swap = pd.DataFrame.from_dict(aug_data_swap)
df_swap.to_csv("random_swap_25percent.csv", index=False)
df_swap.head()
# Out:
#    label                                               text
# 0      1  Is story the and its - bogus characters thin t...
# 1      4  It never it makes quite the to boiling point b...
# 2      2  () Newton through wanders CHARLIE completely n...
# 3      5  ' it s the kind effectively of creepy - scary ...
# 4      4  Diaz, Applegate, and Blair Posey suitably are ...

# %%
df_delete = pd.DataFrame.from_dict(aug_data_delete)
df_delete.to_csv("random_delete_25percent.csv", index=False)
df_delete.head()
# Out:
#    label                                               text
# 0      2  Its thorn (and simple humanity) plundered by s...
# 1      4  ( Scherfig) made will you wondering about the ...
# 2      2      Diane Lane ' performance n ' t Adrian ' from.
# 3      4  Terry is sort of geriatric, which will Eastwoo...
# 4      3                 Empty, - and - street credibility.

# %% [markdown]
# # Using Back-Translation - Google Trans

# %%
# !pip install googletrans==3.1.0a0

# %%
import random
import googletrans
translator = googletrans.Translator()

# Selecting random sample - Picking 5% of the training data - API has limits
df_sample1 = df_train.sample(int(df_train.shape[0]*0.05))

# %%
aug_data_translate = {'label': [], 'text': []}
for ix, (label_field, text_field) in df_sample1.iterrows():
    sentence = [text_field]

    available_langs = list(googletrans.LANGUAGES.keys()) 
    trans_lang = random.choice(available_langs) 
    print(f"Translating to {googletrans.LANGUAGES[trans_lang]}")

    translations = translator.translate(sentence, dest=trans_lang)
    t_text = [t.text for t in translations]
    print(t_text)

    translations_en_random = translator.translate(t_text, src=trans_lang, dest='en') 
    en_text = [t.text for t in translations_en_random]
    print(en_text)

    aug_data_translate['label'].append(label_field)
    aug_data_translate['text'].append(en_text)
# Out:
# ["It 's consistently funny , in an irresistible junior-high way , and consistently free of any gag that would force you to give it a millisecond of thought ."]
# Translating to dutch
# ['Het is altijd grappig, op een onweerstaanbare middelbare school en consequent vrij van elke grap die je zou dwingen er een milliseconde over na te denken.']
# ["It's always funny, in an irresistible high school, and consistently free of any joke that would force you to think about it for a millisecond."]
# ['A muddy psychological thriller rife with miscalculations .']
# Translating to mongolian
# ['Буруу тооцоотой, шаварлаг сэтгэлзүйн триллер.']
# ['Miscalculated, muddy psychological thriller.']
# ['LaBute masterfully balances both Traditional or Modern stories together in a manner that one never overwhelms the other .']
# Translating to javanese
# ['LaBute bisa ngimbangi crita-crita Tradhisional utawa Modern kanthi trampil kanthi cara sing ora nate ngalahake liyane.']
# ['LaBute is able to balance Traditional or Modern stories skillfully in a way that never beats the others.']
# ["It 's a feel-bad ending for a depressing story that throws a bunch of hot-button items in the viewer 's face and asks to be seen as hip , winking social commentary ."]
# Translating to chinese (simplified)
# ['对于一个令人沮丧的故事来说，这是一个令人心痛的结局，在观众的脸上扔了一堆热门项目，并要求被视为时髦的、眨眼的社会评论。']
# ['For a depressing story, this is a heart-wrenching ending, throwing a bunch of hot items on the viewer’s face and asking for social comment that is seen as fashionable, blinking.']
# ["Few of the increasingly far-fetched events that first-time writer-director Neil Burger follows up with are terribly convincing , which is a pity , considering Barry 's terrific performance ."]
# Translating to slovak
# ['Len málo z čoraz viac priťahovaných udalostí, na ktoré nadväzuje prvý scenárista a režisér Neil Burger, je strašne presvedčivých, čo je vzhľadom na úžasné vystúpenie Barryho škoda, škoda.']
# ["Few of the increasingly attracted events, followed by first screenwriter and director Neil Burger, are terribly compelling, which is a shame, given Barry's amazing performance."]
# ["The only pain you 'll feel as the credits roll is your stomach grumbling for some tasty grub ."]
# Translating to punjabi
# ['ਸਿਰਫ ਉਹੀ ਦਰਦ ਜੋ ਤੁਸੀਂ ਮਹਿਸੂਸ ਕਰੋਗੇ ਕਿਉਂਕਿ ਕ੍ਰੈਡਿਟ ਰੋਲ ਤੁਹਾਡਾ ਪੇਟ ਕੁਝ ਸੁਆਦੀ ਗਰੱਬ ਲਈ ਬੁੜਬੁੜਾਈ ਹੈ.']
# ['The only pain you will feel is because the credit roll your stomach is muttering for some delicious grub.']
# ['LaBute was more fun when his characters were torturing each other psychologically and talking about their genitals in public .']
# Translating to amharic
# ['የእሱ ገጸ-ባህሪያት እርስ በእርሱ በሥነ ልቦና እየተሰቃዩ እና ስለ ብልቶቻቸው በአደባባይ ሲነጋገሩ ላቡቴ የበለጠ አስደሳች ነበር ፡፡']
# ['Labute was even more enjoyable as his characters suffered psychologically and talked about their genitals in public.']
# ['An inspiring and heart-affecting film about the desperate attempts of Vietnamese refugees living in U.S. relocation camps to keep their hopes alive in 1975 .']
# Translating to esperanto
# ['Inspira kaj korfekta filmo pri la senesperaj provoj de vjetnamaj rifuĝintoj loĝantaj en usonaj translokaj tendaroj por vivteni siajn esperojn en 1975.']
# ['An inspiring and heartwarming film about the desperate attempts of Vietnamese refugees living in US relocation camps to keep their hopes alive in 1975.']
# ["Ultimately , `` MIB II '' succeeds due to its rapid-fire delivery and enough inspired levity that it ca n't be dismissed as mindless ."]
# Translating to yiddish
# ['לעסאָף, "מיב וו" סאַקסידאַד רעכט צו זיין גיך פייער עקספּרעס און גענוג ינספּייערד לעוויטי אַז עס קען נישט זיין דיסמיסט ווי מיינדלאַס.']
# ['Ultimately, "MIB II" succeeded due to its rapid fire delivery and sufficiently inspired levity that it could not be dismissed as mindless.']
# ["I know that I 'll never listen to Marvin Gaye or the Supremes the same way again"]
# Translating to marathi
# ['मला माहित आहे की मी पुन्हा कधीही मार्व्हन गे किंवा सुप्रीम्स सारखेच ऐकणार नाही']
# ['I know I will never hear the same thing again as Marvin Gay or Supremes']
# ["To paraphrase a line from another Dickens ' novel , Nicholas Nickleby is too much like a fragment of an underdone potato ."]
# Translating to latin
# ['Caesar ex informatione a linea, nova quasi fragmentum crudum nimium Nicolaus Nickleby annuum.']
# ['Caesar set out from her instruction from the line, the new Nicholas Nickleby too much like a fragment of a raw potato.']
# ['Even if the Naipaul original remains the real masterpiece , the movie possesses its own languorous charm .']
# Translating to maori
# ['Ahakoa ko te Naipaul taketake tonu te tino taonga, ka mau i te kiriata tana ake ahuareka.']
# ['While the original Naipaul is still the most rich, the film captures its own charm.']
# ["It ca n't escape its past , and it does n't want to ."]
# Translating to somali
# ['Waxay ka baxsataa waayihiisii \u200b\u200bhore, mana doonayso.']
# ["She escapes from her past, and she doesn't want to."]
# ["Despite apparent motives to the contrary , it ends up being , like ( Seinfeld 's ) revered TV show , about pretty much nothing ."]
# Translating to chinese (traditional)
# ['儘管明顯有相反的動機，但它最終就像（宋飛正傳的）備受推崇的電視節目一樣，幾乎什麼都沒有。']
# ['Despite the obvious opposite motive, it ended up like a well-respected TV show (of Seinfeld’s), with almost nothing.']
# ['Millions of dollars heaped upon a project of such vast proportions need to reap more rewards than spiffy bluescreen technique and stylish weaponry .']
# Translating to bulgarian
# ['Милиони долари, натрупани по проект с толкова големи размери, трябва да извлекат повече награди, отколкото пищната техника на синия екран и стилното оръжие.']
# ['Millions of dollars accumulated on a project of such magnitude must win more rewards than the lavish blue screen technique and stylish weapons.']
# ['Bittersweet comedy/drama full of life , hand gestures , and some really adorable Italian guys .']
# Translating to irish
# ['Coiméide / drámaíocht Bittersweet lán le saol, gothaí láimhe, agus roinnt girseach Iodálach a bhfuil meas mór orthu.']
# ['Bittersweet comedy / drama full of life, hand gestures, and some much appreciated Italian girls.']
# ['A tasty appetizer that leaves you wanting more .']
# Translating to romanian
# ['Un aperitiv gustos care te lasă să îți dorești mai mult.']
# ['A tasty appetizer that leaves you wanting more.']
# ['Extraordinary debut from Josh Koury .']
# Translating to yiddish
# ['ויסערגעוויינלעך דעבוט פֿון Josh Koury.']
# ['Extraordinary debut by Josh Koury.']
# ['( A ) boldly stroked , luridly coloured , uni-dimensional nonsense machine that strokes the eyeballs while it evaporates like so much crypt mist in the brain .']
# Translating to lithuanian
# ['(A) drąsiai glostyta, linksmai nuspalvinta, vienmatė nesąmonių mašina, kuri glosto akių obuolius, o garuoja kaip tiek kriptos miglos smegenyse.']
# ['(A) A boldly stroked, cheerfully colored, one-dimensional nonsense machine that caresses the eyeballs while evaporating like both crypts in the fog of the brain.']
# ["There 's an excellent 90-minute film here ; unfortunately , it runs for 170 ."]
# Translating to english
# ["There 's an excellent 90-minute film here ; unfortunately , it runs for 170 ."]
# ["There 's an excellent 90-minute film here ; unfortunately , it runs for 170 ."]
# ["I 've never seen or heard anything quite like this film , and I recommend it for its originality alone ."]
# Translating to myanmar (burmese)
# ['ဒီရုပ်ရှင်လိုမျိုးကျွန်တော်တစ်ခါမှမမြင်ဖူးခဲ့ဖူးဘူး။']
# ['I have never seen a movie like this.']
# ["is many things -- stoner midnight flick , sci-fi deconstruction , gay fantasia -- but above all it 's a love story as sanguine as its title ."]
# Translating to slovenian
# ['je veliko stvari - stoner midnight flick, znanstvenofantastična dekonstrukcija, gejevska fantazija - predvsem pa gre za ljubezensko zgodbo, tako sangvinično kot njen naslov.']
# ['there are a lot of things - stoner midnight flick, sci-fi deconstruction, gay fantasy - but most of all, it’s a love story, both sanguine and its title.']
# ['even after 90 minutes of playing opposite each other Bullock and Grant still look ill at ease sharing the same scene .']
# Translating to maltese
# ["anke wara 90 minuta li lagħbu faċċata ta 'xulxin Bullock u Grant għadhom jidhru ħażin li jaqsmu l-istess xena."]
# ['even after 90 minutes of playing in front of each other Bullock and Grant still look bad sharing the same scene.']
# ["Schnieder bounces around with limp wrists , wearing tight tummy tops and hip huggers , twirling his hair on his finger and assuming that 's enough to sustain laughs ..."]
# Translating to arabic
# ['يقفز شنايدر معصمي عرجاء ، مرتديًا قمم بطن ضيقة وعناق مفعم بالوركين ، ويلف شعره على إصبعه ويفترض أن هذا يكفي للحفاظ على الضحك ...']
# ['Schneider jumps my lame wrists, wears belly-hugging tops and a hip hug, and wraps his hair on his finger presumably enough to keep him laughing...']
# ["It 's something of the ultimate Scorsese film , with all the stomach-turning violence , colorful New York gang lore and other hallmarks of his personal cinema painted on their largest-ever historical canvas ."]
# Translating to luxembourgish
# ['Et ass eppes vum ultimative Scorsese Film, mat all de Mo-dréiende Gewalt, faarweger New York Bande Lore an aner Markenzeeche vu sengem perséinleche Kino op hirem gréissten historesche Canvas gemoolt.']
# ["It's something of the ultimate Scorsese film, with all the stomach-churning violence, colorful New York gang lore and other trademarks of his personal cinema painted on its largest historic canvas."]
# ["Zellweger 's whiny pouty-lipped poof faced and spindly attempt at playing an ingenue makes her nomination as best actress even more of a an a"]
# Translating to hebrew
# ['שפתו העצבנית של זלווגר המנוצצת והניסיון הדליל לגלם גאון הופכת את המועמדות שלה לשחקנית הטובה עוד יותר']
# ["Zellweger's nervous language and sparse attempt to embody genius make her candidacy for even better actress"]
# ['The fascination comes in the power of the Huston performance , which seems so larger than life and yet so fragile , and in the way the Ivan character accepts the news of his illness so quickly but still finds himself unable to react .']
# Translating to haitian creole
# ["Pasyon a vini nan pouvwa a nan pèfòmans nan Huston, ki sanble se konsa pi gwo pase lavi ak ankò konsa frajil, ak nan fason karaktè Ivan aksepte nouvèl la nan maladi l 'byen vit, men yo toujou jwenn tèt li kapab reyaji."]
# ['The passion comes from the power of Huston’s performance, which seems so much bigger than life and yet so fragile, and in the way Ivan’s character accepts the news of his illness quickly, but still finds himself unable to react.']
# ['It has a way of seeping into your consciousness , with lingering questions about what the film is really getting at .']
# Translating to armenian
# ['Այն ձեր գիտակցության մեջ ներթափանցելու միջոց ունի ՝ տևական հարցերով, թե ինչ է իրականում ստանում ֆիլմը:']
# ['It has a way of penetrating your consciousness by asking you what the film really gets.']
# ['Will undoubtedly play well in European markets , where Mr. Besson is a brand name , and in Asia , where Ms. Shu is an institution , but American audiences will probably find it familiar and insufficiently cathartic .']
# Translating to tajik
# ['Бешубҳа, дар бозорҳои Аврупо, ки дар он ҷаноби Бессон номи брендист ва дар Осиё, ки хонум Шу як муассиса аст, хуб бозӣ хоҳад кард, аммо тамошобинони амрикоӣ эҳтимолан онро ошно ва ба қадри кофӣ бадном мекунанд.']
# ['Sure, it will play well in European markets, where Mr. Besson is a brand name, and in Asia, where Ms. Shu is an institution, but American audiences are likely to recognize it and discredit it enough.']
# ["Brown 's saga , like many before his , makes for snappy prose but a stumblebum of a movie ."]
# Translating to khmer
# ['បិសាចរបស់ប្រោនដូចមនុស្សជាច្រើនមុនពេលគាត់បង្កើតឱ្យមានសំដីសុភាពរាបសាប៉ុន្តែភាពរអាក់រអួលនៃខ្សែភាពយន្ត។']
# ["Brown's monster, like many before him, creates the gentle but awkward tone of the film."]
# ['Yet another entry in the sentimental oh-those-wacky-Brits genre that was ushered in by The Full Monty and is still straining to produce another smash hit .']
# Translating to german
# ['Ein weiterer Eintrag im sentimentalen Genre der ach-diesen-verrückten Briten, das von The Full Monty eingeläutet wurde und immer noch bemüht ist, einen weiteren Hit zu produzieren.']
# ['Another entry in the oh-these-crazy British sentimental genre heralded by The Full Monty and still struggling to produce another hit.']
# ['Much smarter and more attentive than it first sets out to be .']
# Translating to spanish
# ['Mucho más inteligente y atento de lo que parece.']
# ['Much more intelligent and attentive than it seems.']
# ['An intoxicating experience .']
# Translating to greek
# ['Μια μεθυστική εμπειρία.']
# ['An intoxicating experience.']
# ["And there 's the inimitable Diaz , holding it all together ."]
# Translating to catalan
# ["I hi ha l 'inimitable Díaz, que ho manté tot junt."]
# ['And there is the inimitable Diaz, who keeps it all together.']
# ["But the problem with Wendigo , for all its effective moments , is n't really one of resources ."]
# Translating to malagasy
# ["Fa ny olana amin'i Wendigo, mandritra ny fotoana mahomby rehetra dia tsy tena iray amin'ireo loharano."]
# ['But the problem with Wendigo, during all successful times is not really one of the sources.']
# ["For a film that 's being advertised as a comedy , Sweet Home Alabama is n't as funny as you 'd hoped ."]
# Translating to somali
# ['Filim loo xayeysiinayo sida majaajilada, Guriga macaan ee Alabama ma ahan mid qosol badan sidaad rajeyneysay.']
# ['A film advertised as a comedy, The Sweet Home of Alabama is not as funny as you would expect.']
# ["A behind the scenes look at the training and dedication that goes into becoming a world-class fencer and the champion that 's made a difference to NYC inner-city youth ."]
# Translating to persian
# ['نگاهی به پشت صحنه آموزش و فداکاری که برای تبدیل شدن به یک شمشیرباز کلاس جهانی و قهرمانی انجام می شود که باعث ایجاد تفاوت در جوانان شهر نیویورک می شود.']
# ['A behind-the-scenes look at the training and dedication that goes into becoming a world-class swordsman and champion who makes a difference to New York City youth.']
# ["It 's the kind of under-inspired , overblown enterprise that gives Hollywood sequels a bad name ."]
# Translating to scots gaelic
# ['Is e seo an seòrsa iomairt fo-bhrosnaichte a tha a ’toirt droch ainm dha sreathan Hollywood.']
# ['This is the kind of under-inspired campaign that is giving Hollywood series a bad name.']
# ['The story is a rather simplistic one : grief drives her , love drives him , and a second chance to find love in the most unlikely place - it struck a chord in me .']
# Translating to georgian
# ['სიუჟეტი საკმაოდ გამარტივებულია: მწუხარება უბიძგებს მას, სიყვარული მას უბიძგებს და მეორე შანსი იპოვნოს სიყვარული ყველაზე ნაკლებად სავარაუდო ადგილას - ეს ჩემში აკორდს მოჰყვა.']
# ['The story is quite simplistic: sadness pushes him, love pushes him, and a second chance to find love in the least likely place - it brought a chord in me.']
# ['The sort of picture in which , whenever one of the characters has some serious soul searching to do , they go to a picture-perfect beach during sunset .']
# Translating to portuguese
# ['O tipo de foto em que, sempre que um dos personagens tem uma séria busca da alma a fazer, eles vão para uma praia perfeita durante o pôr do sol.']
# ['The kind of shot where whenever one of the characters has a serious soul-searching to do, they head to a perfect beach at sunset.']
# ["It 's a scorcher ."]
# Translating to german
# ['Es ist ein Scorcher .']
# ["It's a scorcher."]
# ['An honest , sensitive story from a Vietnamese point of view .']
# Translating to chinese (traditional)
# ['從越南的角度來看，這是一個誠實、敏感的故事。']
# ['From a Vietnamese perspective, this is an honest and sensitive story.']
# ['A very pretty after-school special .']
# Translating to azerbaijani
# ['Çox yaraşıqlı bir məktəb sonrası xüsusi.']
# ['A very nice after-school special.']
# ["Overall , it 's a pretty mediocre family film ."]
# Translating to hebrew
# ['בסך הכל, זהו סרט משפחתי בינוני למדי.']
# ['Overall, this is a pretty mediocre family movie.']
# ["You ca n't believe anyone would really buy this stuff ."]
# Translating to basque
# ['Ezin duzu sinetsi inork gauza horiek erosiko lituzkeenik.']
# ['You can’t believe anyone would buy these things.']
# ["They exist for hushed lines like `` They 're back ! ''"]
# Translating to afrikaans
# ["Hulle bestaan \u200b\u200bvir gedempte lyne soos 'Hulle is terug! ''"]
# ["They exist for muted lines like 'They're back! ''"]
# ['What saves it ... and makes it one of the better video-game-based flicks , is that the film acknowledges upfront that the plot makes no sense , such that the lack of linearity is the point of emotional and moral departure for protagonist Alice .']
# Translating to croatian
# ['Ono što ga spašava ... i čini jednim od boljih poteza temeljenih na video igrama, jest to što film unaprijed priznaje da radnja nema smisla, tako da je nedostatak linearnosti točka emocionalnog i moralnog odlaska protagonistice Alice .']
# ['What saves him ... and makes him one of the better moves based on video games, is that the film admits in advance that the plot makes no sense, so the lack of linearity is the point of the protagonist Alice’s emotional and moral departure.']
# ["Despite engaging offbeat touches , Knockaround Guys rarely seems interested in kicking around a raison d'etre that 's as fresh-faced as its young-guns cast ."]
# Translating to swahili
# ["Licha ya kushikilia kugusa kwa bahati mbaya, Guys wa Knockaround mara chache anaonekana kupenda kupiga mateke karibu na raison d'etre ambayo ni sura mpya kama bunduki zake ndogo."]
# ["Despite holding on to an unfortunate touch, the Guys of Knockaround rarely seem to like kicking around raison d'etre which is a new shape like his small guns."]
# ['The vistas are sweeping and the acting is far from painful .']
# Translating to malayalam
# ['വിസ്തകൾ തൂത്തുവാരുന്നു, അഭിനയം വേദനാജനകമാണ്.']
# ['The vistas are sweeping, and the acting is painful.']
# ['All three descriptions suit Evelyn , a besotted and obvious drama that tells us nothing new .']
# Translating to sesotho
# ['Litlhaloso tsena tse tharo li tšoanela Evelyn, tšoantšiso e khabisitsoeng le e totobetseng e sa re bolelleng letho le lecha.']
# ['All three of these descriptions fit Evelyn, a beautiful and vivid play that tells us nothing new.']
# ['Immediately .']
# Translating to latvian
# ['Nekavējoties.']
# ['Immediately.']
# ["A psychological thriller with a smart script and an obsessive-compulsive 's attention to detail ."]
# Translating to corsican
# ['Un thriller psicologicu cù un script intelligente è una attenzione obsessive-compulsiva per i dettagli.']
# ['A psychological thriller with an intelligent script and an obsessive-compulsive attention to detail.']
# ['Miller tells this very compelling tale with little fuss or noise , expertly plucking tension from quiet .']
# Translating to hebrew
# ['מילר מספר את הסיפור המשכנע מאוד הזה עם מעט מהומה או רעש, ומוציא מומחיות בשקט במומחיות.']
# ['Miller tells this very compelling story with little fuss or noise, and quietly brings out expertise in expertise.']
# ['This is a film brimming with detail and nuance and one that speaks volumes about the ability of the human spirit to find solace in events that could easily crush it forever .']
# Translating to georgian
# ['ეს არის დეტალებით და ნიუანსებით სავსე ფილმი, რომელიც ბევრ რამეზე მეტყველებს ადამიანის სულის უნარზე, იპოვნოს დამამშვიდებელი მოვლენები, რაც ადვილად გაანადგურებს მას სამუდამოდ.']
# ['It is a film full of details and nuances that speaks volumes about the human soul’s ability to find soothing events that will easily destroy it forever.']
# ['A quietly moving look back at what it was to be Iranian-American in 1979 .']
# Translating to albanian
# ['Një vështrim i qetë dhe tërheqës prapa në atë që do të ishe irano-amerikan në 1979.']
# ['A calm and catchy look back at what you would have been Iranian-American in 1979.']
# ["It moves quickly , adroitly , and without fuss ; it does n't give you time to reflect on the inanity -- and the Cold War datedness -- of its premise ."]
# Translating to hebrew
# ['זה נע במהירות, באדיבות וללא מהומה; זה לא נותן לך זמן להרהר בדמיון - ובימי המלחמה הקרה - של הנחת היסוד שלה.']
# ['It moves quickly, courteously and without fuss; It does not give you time to reflect on the imagination - and in the days of the Cold War - of its premise.']
# ['Must-see viewing for anyone involved in the high-tech industry .']
# Translating to xhosa
# ['Kufuneka ubukele ukubonwa kwakhe nabani na obandakanyekayo kushishino lobuchwephesha obuphezulu.']
# ['You have to watch the sight of anyone involved in the high-tech industry.']
# ["It 's sobering , particularly if anyone still thinks this conflict can be resolved easily , or soon ."]
# Translating to bengali
# ['এটি খুব মনোরম, বিশেষত যদি কেউ এখনও মনে করেন যে এই বিরোধটি সহজেই বা শীঘ্রই সমাধান করা যেতে পারে।']
# ['This is very pleasant, especially if one still thinks that this dispute can be resolved easily or soon.']
# ['more precious than perspicacious']
# Translating to thai
# ['ล้ำค่ากว่าความเห็นแก่ตัว']
# ['more valuable than selfishness']
# ["You 're better off staying home and watching The X-Files ."]
# Translating to georgian
# ['თქვენ ჯობია დარჩეთ სახლში და უყუროთ X-Files- ს.']
# ['You better stay home and watch the X-Files.']
# ['Sets animation back 30 years , musicals back 40 years and Judaism back at least 50 .']
# Translating to marathi
# ['Years० वर्ष मागे अ\u200dॅनिमेशन, icals० वर्षांची संगीत आणि ज्यू धर्म किमान ism० परत सेट करते.']
# ['Years0 years back animation, icals0 years music and Judaism at least set ism0 back.']
# ["It 's best to avoid imprisonment with the dull , nerdy folks that inhabit Cherish ."]
# Translating to turkish
# ["Cherish'te yaşayan sıkıcı, inek insanlarla hapse girmekten kaçınmak en iyisidir."]
# ["It's best to avoid going to jail with the boring, nerdy people living in Cherish."]
# ["`` Birthday Girl '' is an actor 's movie first and foremost ."]
# Translating to khmer
# ["`` ក្មេងស្រីខួបកំណើត 'គឺជាខ្សែភាពយន្តរបស់តារាសម្តែងមុនគេនិងមុនគេ។"]
# ["`` Birthday Girl 'is the film of the first and foremost actress."]
# ["Whaley 's determination to immerse you in sheer , unrelenting wretchedness is exhausting ."]
# Translating to polish
# ['Determinacja Whaleya, by zanurzyć cię w czystej, nieubłaganej nędzy, jest wyczerpująca.']
# ["Whaley's determination to immerse you in pure, unrelenting poverty is exhausting."]
# ["Like Schindler 's List , The Grey Zone attempts to be grandiloquent , but ends up merely pretentious -- in a grisly sort of way ."]
# Translating to malay
# ["Seperti Schindler's List, The Gray Zone berusaha untuk menjadi mulia, tetapi akhirnya hanya sombong - dengan cara yang mengerikan."]
# ['Like Schindler’s List, The Gray Zone strives to be noble, but ends up just arrogant - in a horrible way.']
# ['Good car chases , great fight scenes , and a distinctive blend of European , American and Asian influences .']
# Translating to kazakh
# ['Жақсы автокөлік қуғын-сүргін, керемет жекпе-жек көріністері және еуропалық, американдық және азиялық әсерлердің ерекше қоспасы.']
# ['Good car repression, great fighting scenes and a unique mix of European, American and Asian influences.']
# ['A crude teen-oriented variation on a theme that the playwright Craig Lucas explored with infinitely more grace and eloquence in his Prelude to a Kiss .']
# Translating to hebrew
# ['וריאציה גסה העוסקת בבני נוער על נושא שהמחזאי קרייג לוקאס חקר באינסוף יותר חן ורהיטות בפרלוד שלו לנשיקה.']
# ['A rude variation that deals with teens on a subject that playwright Craig Lucas has endlessly explored more grace and fluency in his prelude to a kiss.']
# ['An unfortunate title for a film that has nothing endearing about it .']
# Translating to czech
# ['Nešťastný název filmu, který na tom nemá nic hezkého.']
# ['The unfortunate title of the film, which has nothing nice about it.']
# ['And it marks him as one of the most interesting writer/directors working today .']
# Translating to catalan
# ['I el marca com un dels escriptors / directors més interessants que treballen avui.']
# ['And he marks it as one of the most interesting writers / directors working today.']
# ["( Clooney 's ) debut can be accused of being a bit undisciplined , but it has a tremendous , offbeat sense of style and humor that suggests he was influenced by some of the filmmakers who have directed him , especially the Coen brothers and Steven Soderbergh ."]
# Translating to kazakh
# ['(Клуни) дебютін аздап тәртіпті деп айыптауға болады, бірақ оның стилі мен әзіл-оспағының орасан зор мәні бар, бұл оған оны режиссер еткен кейбір кинорежиссерлердің, әсіресе, ағайынды Коун мен Стивен Содербергтің әсер еткендігін көрсетеді.']
# ["(Clooney) 's debut can be accused of being a bit disciplined, but his style and humor are huge, indicating that he was influenced by some of the filmmakers who directed it, especially the Cohen brothers and Stephen Soderbergh."]
# ["Turturro is fabulously funny and over the top as a ` very sneaky ' butler who excels in the art of impossible disappearing/reappearing acts"]
# Translating to chinese (simplified)
# ['Turturro 非常有趣，并且是一位“非常狡猾”的管家，擅长不可能消失/重新出现的行为艺术。']
# ['Turturro is very interesting and is a "very cunning" butler, good at performance art that can\'t disappear/reappear.']
# ['At once a testament to the divine calling of education and a demonstration of the painstaking process of imparting knowledge .']
# Translating to danish
# ['Straks et bevis på den guddommelige kaldelse af uddannelse og en demonstration af den omhyggelige proces med at formidle viden.']
# ['Immediately a proof of the divine calling of education and a demonstration of the careful process of imparting knowledge.']
# ["Lisa Rinzler 's cinematography may be lovely , but Love Liza 's tale itself virtually collapses into an inhalant blackout , maintaining consciousness just long enough to achieve callow pretension ."]
# Translating to hmong
# ["Lisa Rinzler's cinematography tej zaum yuav ntxim hlub, tab sis Hlub Liza zaj dab neeg nws tus kheej sib tsoo mus rau hauv ib qho kev tsaus muag tsis zoo, tswj kev nco qab tsuas yog ntev txaus kom ua tiav callow pretension."]
# ["Lisa Rinzler's cinematography may be cute, but Love Liza's story itself crashes into a bad faint, managing memory only long enough to complete callow pretension."]
# ["You 'd think by now America would have had enough of plucky British eccentrics with hearts of gold ."]
# Translating to portuguese
# ['Você pensaria que agora a América já estaria farta de destemidos excêntricos britânicos com corações de ouro.']
# ['You would think that by now America would be fed up with fearless British eccentrics with hearts of gold.']
# ['The script ?']
# Translating to arabic
# ['النص ؟']
# ['Text ?']
# ["It 's fitting that a movie as artificial and soulless as The Country Bears owes its genesis to an animatronic display at Disneyland ."]
# Translating to kazakh
# ['«Ел аюлары» сияқты жасанды және жансыз фильм өзінің генезисіне Диснейлендтегі аниматрондық дисплейге қарыздар болғаны орынды.']
# ['An artificial and inanimate film, such as "Country Bears", owes its genesis to the animated display at Disneyland.']
# ['For most of the distance the picture provides a satisfyingly unsettling ride into the dark places of our national psyche .']
# Translating to albanian
# ['Për pjesën më të madhe të distancës, fotografia siguron një udhëtim kënaqës shqetësues në vendet e errëta të psikikës sonë kombëtare.']
# ['For most of the distance, photography provides a delightfully enjoyable journey into the dark places of our national psyche.']
# ["Those with a modicum of patience will find in these characters ' foibles a timeless and unique perspective ."]
# Translating to latin
# ['Illae sunt valde modici patientiae et invenies in his characteribus, disputationi et admirator a unique prospectu.']
# ['Those with a modicum of patience you will find these characters, discussed and admired a unique perspective.']
# ['Like a skillful fisher , the director uses the last act to reel in the audience since its poignancy hooks us completely .']
# Translating to swedish
# ['Som en skicklig fiskare använder regissören den sista akten för att rulla in publiken eftersom dess gripande hakar oss helt.']
# ['As a skilled fisherman, the director uses the last act to roll in the audience because its gripping hooks us completely.']
# ['More of a career curio than a major work .']
# Translating to romanian
# ['Mai mult o curiozitate în carieră decât o operă majoră.']
# ['More of a career curiosity than a major opera.']
# ['Effective in all its aspects , Margarita Happy Hour represents an auspicious feature debut for Chaiken .']
# Translating to slovak
# ['Po všetkých stránkach Margarita Happy Hour predstavuje pre Chaiken priaznivý celovečerný debut.']
# ['In all respects, Margarita Happy Hour is a favorable feature debut for Chaiken.']
# ['I had to look away - this was god awful .']
# Translating to greek
# ['Έπρεπε να κοιτάξω μακριά - αυτό ήταν φοβερό.']
# ['I had to look away - that was awesome.']
# ['ZigZag might have been richer and more observant if it were less densely plotted .']
# Translating to marathi
# ['जर कमी दाब रचला गेला असेल तर ढिगझॅग कदाचित श्रीमंत आणि अधिक निरीक्षक झाला असेल.']
# ['If less pressure had been created, Dhigzag might have become richer and more observant.']
# ['There is something in Full Frontal , I guess , about artifice and acting and how it distorts reality for people who make movies and watch them , but like most movie riddles , it works only if you have an interest in the characters you see .']
# Translating to basque
# ['Badago zerbait Full Frontal-en, asmatzen dut, artifizioari eta antzezpenari buruz eta errealitatea nola desitxuratzen duen filmak egiten dituztenak eta ikusten dituzten pertsonentzat, baina filmen igarkizun gehienak bezala, ikusten dituzun pertsonaiekiko interesa baduzu soilik funtzionatzen du.']
# ['There’s something in Full Frontal, I guess, about artifice and acting and how it distorts reality for people who make and watch movies, but like most movie riddles, it only works if you’re interested in the characters you see.']
# ['Naomi Watts is terrific as Rachel ; her petite frame and vulnerable persona emphasising her plight and isolation .']
# Translating to korean
# ['Naomi Watts는 Rachel만큼 훌륭합니다. 그녀의 곤경과 고립을 강조하는 그녀의 몸집이 작은 몸매와 취약한 인물.']
# ['Naomi Watts is as good as Rachel. Her petite body and vulnerable figure highlight her plight and isolation.']
# ['Wow , so who knew Charles Dickens could be so light-hearted ?']
# Translating to uzbek
# ["Voy, demak, Charlz Dikkens bu qadar yengil bo'lishini kim bilgan?"]
# ["Voy, demak, Charlz Dikkens bu qadar yengil bo'lishini kim bilgan?"]
# ["Even if you 've seen `` Stomp '' ( the stage show ) , you still have to see this !"]
# Translating to english
# ["Even if you 've seen `` Stomp '' ( the stage show ) , you still have to see this !"]
# ["Even if you 've seen `` Stomp '' ( the stage show ) , you still have to see this !"]
# ['The story suffers a severe case of oversimplification , superficiality and silliness .']
# Translating to hausa
# ['The story suffers a severe case of oversimplification , superficiality and silliness .']
# ['The story suffers a severe case of oversimplification , superficiality and silliness .']
# ['The respective charms of Sandra Bullock and Hugh Grant have worn threadbare .']
# Translating to ukrainian
# ['The respective charms of Sandra Bullock and Hugh Grant have worn threadbare .']
# ['The respective charms of Sandra Bullock and Hugh Grant have worn threadbare .']
# ['This is the kind of movie during which you want to bang your head on the seat in front of you , at its cluelessness , at its idiocy , at its utterly misplaced earnestness .']
# Translating to vietnamese
# ['This is the kind of movie during which you want to bang your head on the seat in front of you , at its cluelessness , at its idiocy , at its utterly misplaced earnestness .']
# ['This is the kind of movie during which you want to bang your head on the seat in front of you , at its cluelessness , at its idiocy , at its utterly misplaced earnestness .']
# ["The people in Jessica are so recognizable and true that , as in real life , we 're never sure how things will work out ."]
# Translating to xhosa
# ["The people in Jessica are so recognizable and true that , as in real life , we 're never sure how things will work out ."]
# ["The people in Jessica are so recognizable and true that , as in real life , we 're never sure how things will work out ."]
# ["It 's kind of sad that so many people put so much time and energy into this turkey ."]
# Translating to portuguese
# ["It 's kind of sad that so many people put so much time and energy into this turkey ."]
# ["It 's kind of sad that so many people put so much time and energy into this turkey ."]
# ['It reduces the complexities to bromides and slogans and it gets so preachy-keen and so tub-thumpingly loud it makes you feel like a chump just for sitting through it .']
# Translating to arabic
# ['It reduces the complexities to bromides and slogans and it gets so preachy-keen and so tub-thumpingly loud it makes you feel like a chump just for sitting through it .']
# ['It reduces the complexities to bromides and slogans and it gets so preachy-keen and so tub-thumpingly loud it makes you feel like a chump just for sitting through it .']
# ["With a `` Spy Kids '' sequel opening next week , why bother with a contemptible imitator starring a `` SNL '' has-been acting like an 8-year-old channeling Roberto Benigni ?"]
# Translating to javanese
# ["With a `` Spy Kids '' sequel opening next week , why bother with a contemptible imitator starring a `` SNL '' has-been acting like an 8-year-old channeling Roberto Benigni ?"]
# ["With a `` Spy Kids '' sequel opening next week , why bother with a contemptible imitator starring a `` SNL '' has-been acting like an 8-year-old channeling Roberto Benigni ?"]
# ['Underachieves only in not taking the Shakespeare parallels quite far enough .']
# Translating to khmer
# ['Underachieves only in not taking the Shakespeare parallels quite far enough .']
# ['Underachieves only in not taking the Shakespeare parallels quite far enough .']
# ['Though not for everyone , The Guys is a somber trip worth taking .']
# Translating to russian
# ['Though not for everyone , The Guys is a somber trip worth taking .']
# ['Though not for everyone , The Guys is a somber trip worth taking .']
# ['The film is powerful , accessible and funny .']
# Translating to corsican
# ['The film is powerful , accessible and funny .']
# ['The film is powerful , accessible and funny .']
# ['In a 102-minute film , Aaliyah gets at most 20 minutes of screen time .']
# Translating to odia
# ['In a 102-minute film , Aaliyah gets at most 20 minutes of screen time .']
# ['In a 102-minute film , Aaliyah gets at most 20 minutes of screen time .']
# ["It 's anchored by splendid performances from an honored screen veteran and a sparkling newcomer who instantly transform themselves into a believable mother/daughter pair ."]
# Translating to myanmar (burmese)
# ["It 's anchored by splendid performances from an honored screen veteran and a sparkling newcomer who instantly transform themselves into a believable mother/daughter pair ."]
# ["It 's anchored by splendid performances from an honored screen veteran and a sparkling newcomer who instantly transform themselves into a believable mother/daughter pair ."]
# ["It 's excessively quirky and a little underconfident in its delivery , but otherwise this is the best ` old neighborhood ' project since Christopher Walken kinda romanced Cyndi Lauper in The Opportunists ."]
# Translating to uzbek
# ["It 's excessively quirky and a little underconfident in its delivery , but otherwise this is the best ` old neighborhood ' project since Christopher Walken kinda romanced Cyndi Lauper in The Opportunists ."]
# ["It 's excessively quirky and a little underconfident in its delivery , but otherwise this is the best ` old neighborhood ' project since Christopher Walken kinda romanced Cyndi Lauper in The Opportunists ."]
# ['An uneasy mix of run-of-the-mill raunchy humor and seemingly sincere personal reflection .']
# Translating to arabic
# ['An uneasy mix of run-of-the-mill raunchy humor and seemingly sincere personal reflection .']
# ['An uneasy mix of run-of-the-mill raunchy humor and seemingly sincere personal reflection .']
# ['Too bland and fustily tasteful to be truly prurient .']
# Translating to maori
# ['Too bland and fustily tasteful to be truly prurient .']
# ['Too bland and fustily tasteful to be truly prurient .']
# ["Instead of panoramic sweep , Kapur gives us episodic choppiness , undermining the story 's emotional thrust ."]
# Translating to chinese (simplified)
# ["Instead of panoramic sweep , Kapur gives us episodic choppiness , undermining the story 's emotional thrust ."]
# ["Instead of panoramic sweep , Kapur gives us episodic choppiness , undermining the story 's emotional thrust ."]
# ['Just plain silly .']
# Translating to serbian
# ['Just plain silly .']
# ['Just plain silly .']
# ['A time machine , a journey back to your childhood , when cares melted away in the dark theater , and films had the ability to mesmerize , astonish and entertain .']
# Translating to hausa
# ['A time machine , a journey back to your childhood , when cares melted away in the dark theater , and films had the ability to mesmerize , astonish and entertain .']
# ['A time machine , a journey back to your childhood , when cares melted away in the dark theater , and films had the ability to mesmerize , astonish and entertain .']
# ['Stitch is a bad mannered , ugly and destructive little **** .']
# Translating to filipino
# ['Stitch is a bad mannered , ugly and destructive little **** .']
# ['Stitch is a bad mannered , ugly and destructive little **** .']
# ["Sitting in the third row of the IMAX cinema at Sydney 's Darling Harbour , but I sometimes felt as though I was in the tiny two seater plane that carried the giant camera around Australia , sweeping and gliding , banking and hovering over some of the most not"]
# Translating to somali
# ["Sitting in the third row of the IMAX cinema at Sydney 's Darling Harbour , but I sometimes felt as though I was in the tiny two seater plane that carried the giant camera around Australia , sweeping and gliding , banking and hovering over some of the most not"]
# ["Sitting in the third row of the IMAX cinema at Sydney 's Darling Harbour , but I sometimes felt as though I was in the tiny two seater plane that carried the giant camera around Australia , sweeping and gliding , banking and hovering over some of the most not"]
# ["It 's petty thievery like this that puts flimsy flicks like this behind bars"]
# Translating to chinese (simplified)
# ["It 's petty thievery like this that puts flimsy flicks like this behind bars"]
# ["It 's petty thievery like this that puts flimsy flicks like this behind bars"]
# ["It 's a hellish , numbing experience to watch , and it does n't offer any insights that have n't been thoroughly debated in the media already , back in the Dahmer heyday of the mid - '90s ."]
# Translating to portuguese
# ["It 's a hellish , numbing experience to watch , and it does n't offer any insights that have n't been thoroughly debated in the media already , back in the Dahmer heyday of the mid - '90s ."]
# ["It 's a hellish , numbing experience to watch , and it does n't offer any insights that have n't been thoroughly debated in the media already , back in the Dahmer heyday of the mid - '90s ."]
# ['This ludicrous film is predictable at every turn .']
# Translating to malayalam
# ['This ludicrous film is predictable at every turn .']
# ['This ludicrous film is predictable at every turn .']
# ['Blessed with two fine , nuanced lead performances .']
# Translating to german
# ['Blessed with two fine , nuanced lead performances .']
# ['Blessed with two fine , nuanced lead performances .']
# ["But here 's a movie about it anyway ."]
# Translating to hungarian
# ["But here 's a movie about it anyway ."]
# ["But here 's a movie about it anyway ."]
# ['Extremely confusing .']
# Translating to odia
# ['Extremely confusing .']
# ['Extremely confusing .']
# ["There 's a part of us that can not help be entertained by the sight of someone getting away with something ."]
# Translating to chichewa
# ["There 's a part of us that can not help be entertained by the sight of someone getting away with something ."]
# ["There 's a part of us that can not help be entertained by the sight of someone getting away with something ."]
# ['Well , it does go on forever .']
# Translating to hawaiian
# ['Well , it does go on forever .']
# ['Well , it does go on forever .']
# ['Often overwrought and at times positively irritating , the film turns into an engrossing thriller almost in spite of itself .']
# Translating to cebuano
# ['Often overwrought and at times positively irritating , the film turns into an engrossing thriller almost in spite of itself .']
# ['Often overwrought and at times positively irritating , the film turns into an engrossing thriller almost in spite of itself .']
# ["It manages to squeeze by on Angelina Jolie 's surprising flair for self-deprecating comedy ."]
# Translating to bengali
# ["It manages to squeeze by on Angelina Jolie 's surprising flair for self-deprecating comedy ."]
# ["It manages to squeeze by on Angelina Jolie 's surprising flair for self-deprecating comedy ."]
# ["It 's a documentary that says that the alternate sexuality meant to set you free may require so much relationship maintenance that celibacy can start looking good ."]
# Translating to tamil
# ["It 's a documentary that says that the alternate sexuality meant to set you free may require so much relationship maintenance that celibacy can start looking good ."]
# ["It 's a documentary that says that the alternate sexuality meant to set you free may require so much relationship maintenance that celibacy can start looking good ."]
# ['Some , like Ballistic , arrive stillborn ... looking like the beaten , well-worn video box cover of seven years into the future .']
# Translating to german
# ['Some , like Ballistic , arrive stillborn ... looking like the beaten , well-worn video box cover of seven years into the future .']
# ['Some , like Ballistic , arrive stillborn ... looking like the beaten , well-worn video box cover of seven years into the future .']
# ['While dutifully pulling on heartstrings , directors Dean Deblois and Chris Sanders valiantly keep punching up the mix .']
# Translating to amharic
# ['While dutifully pulling on heartstrings , directors Dean Deblois and Chris Sanders valiantly keep punching up the mix .']
# ['While dutifully pulling on heartstrings , directors Dean Deblois and Chris Sanders valiantly keep punching up the mix .']
# ["It 's quite another to feel physically caught up in the process ."]
# Translating to lithuanian
# ["It 's quite another to feel physically caught up in the process ."]
# ["It 's quite another to feel physically caught up in the process ."]
# ["They kept much of the plot but jettisoned the stuff that would make this a moving experience for people who have n't read the book ."]
# Translating to russian
# ["They kept much of the plot but jettisoned the stuff that would make this a moving experience for people who have n't read the book ."]
# ["They kept much of the plot but jettisoned the stuff that would make this a moving experience for people who have n't read the book ."]
# ['A creaky staircase gothic .']
# Translating to uzbek
# ['A creaky staircase gothic .']
# ['A creaky staircase gothic .']
# ["The movie ends with outtakes in which most of the characters forget their lines and just utter ` uhhh , ' which is better than most of the writing in the movie ."]
# Translating to latin
# ["The movie ends with outtakes in which most of the characters forget their lines and just utter ` uhhh , ' which is better than most of the writing in the movie ."]
# ["The movie ends with outtakes in which most of the characters forget their lines and just utter ` uhhh , ' which is better than most of the writing in the movie ."]
# ['Painfully padded .']
# Translating to swedish
# ['Painfully padded .']
# ['Painfully padded .']
# ["Slow and ponderous , but Rohmer 's drama builds to an intense indoor drama about compassion , sacrifice , and Christian love in the face of political corruption ."]
# Translating to serbian
# ["Slow and ponderous , but Rohmer 's drama builds to an intense indoor drama about compassion , sacrifice , and Christian love in the face of political corruption ."]
# ["Slow and ponderous , but Rohmer 's drama builds to an intense indoor drama about compassion , sacrifice , and Christian love in the face of political corruption ."]
# ["It 's a big idea , but the film itself is small and shriveled ."]
# Translating to bengali
# ["It 's a big idea , but the film itself is small and shriveled ."]
# ["It 's a big idea , but the film itself is small and shriveled ."]
# ['A high-spirited buddy movie about the reunion of Berlin anarchists who face arrest 15 years after their crime .']
# Translating to samoan
# ['A high-spirited buddy movie about the reunion of Berlin anarchists who face arrest 15 years after their crime .']
# ['A high-spirited buddy movie about the reunion of Berlin anarchists who face arrest 15 years after their crime .']
# ["I 'll put it this way : If you 're in the mood for a melodrama narrated by talking fish , this is the movie for you ."]
# Translating to sinhala
# ["I 'll put it this way : If you 're in the mood for a melodrama narrated by talking fish , this is the movie for you ."]
# ["I 'll put it this way : If you 're in the mood for a melodrama narrated by talking fish , this is the movie for you ."]
# ["In other words , about as bad a film you 're likely to see all year ."]
# Translating to indonesian
# ["In other words , about as bad a film you 're likely to see all year ."]
# ["In other words , about as bad a film you 're likely to see all year ."]
# ['Made me unintentionally famous -- as the queasy-stomached critic who staggered from the theater and blacked out in the lobby .']
# Translating to zulu
# ['Made me unintentionally famous -- as the queasy-stomached critic who staggered from the theater and blacked out in the lobby .']
# ['Made me unintentionally famous -- as the queasy-stomached critic who staggered from the theater and blacked out in the lobby .']
# ['Admirably ambitious but self-indulgent .']
# Translating to uzbek
# ['Admirably ambitious but self-indulgent .']
# ['Admirably ambitious but self-indulgent .']
# ["The movie does n't generate a lot of energy ."]
# Translating to spanish
# ["The movie does n't generate a lot of energy ."]
# ["The movie does n't generate a lot of energy ."]
# ['Pretty much sucks , but has a funny moment or two .']
# Translating to khmer
# ['Pretty much sucks , but has a funny moment or two .']
# ['Pretty much sucks , but has a funny moment or two .']
# ["I could n't recommend this film more ."]
# Translating to latin
# ["I could n't recommend this film more ."]
# ["I could n't recommend this film more ."]
# ['Surprisingly powerful and universal .']
# Translating to sundanese
# ['Surprisingly powerful and universal .']
# ['Surprisingly powerful and universal .']
# ['Despite its flaws , Secretary stays in your head and makes you question your own firmly held positions .']
# Translating to hebrew
# ['Despite its flaws , Secretary stays in your head and makes you question your own firmly held positions .']
# ['Despite its flaws , Secretary stays in your head and makes you question your own firmly held positions .']
# ['Terrific casting and solid execution give all three stories life .']
# Translating to hawaiian
# ['Terrific casting and solid execution give all three stories life .']
# ['Terrific casting and solid execution give all three stories life .']
# ['Disney again ransacks its archives for a quick-buck sequel .']
# Translating to hausa
# ['Disney again ransacks its archives for a quick-buck sequel .']
# ['Disney again ransacks its archives for a quick-buck sequel .']
# ['A delectable and intriguing thriller filled with surprises , Read My Lips is an original .']
# Translating to dutch
# ['A delectable and intriguing thriller filled with surprises , Read My Lips is an original .']
# ['A delectable and intriguing thriller filled with surprises , Read My Lips is an original .']
# ["Peralta 's mythmaking could have used some informed , adult hindsight ."]
# Translating to bosnian
# ...
# ['A tired , predictable , bordering on offensive , waste of time , money and celluloid .']
# Translating to cebuano
# ['A tired , predictable , bordering on offensive , waste of time , money and celluloid .']
# ['A tired , predictable , bordering on offensive , waste of time , money and celluloid .']
# ['One of the most slyly exquisite anti-adult movies ever made .']
# Translating to macedonian
# ['One of the most slyly exquisite anti-adult movies ever made .']
# ['One of the most slyly exquisite anti-adult movies ever made .']
# ['Many insightful moments .']
# Translating to kazakh
# ['Many insightful moments .']
# ['Many insightful moments .']
# ['Largely , this is a movie that also does it by the numbers .']
# Translating to chichewa
# ['Largely , this is a movie that also does it by the numbers .']
# ['Largely , this is a movie that also does it by the numbers .']
# ["It 's mildly entertaining , especially if you find comfort in familiarity ."]
# Translating to polish
# ["It 's mildly entertaining , especially if you find comfort in familiarity ."]
# ["It 's mildly entertaining , especially if you find comfort in familiarity ."]
# ["`` White Oleander , '' the movie , is akin to a Reader 's Digest condensed version of the source material ."]
# Translating to italian
# ["`` White Oleander , '' the movie , is akin to a Reader 's Digest condensed version of the source material ."]
# ["`` White Oleander , '' the movie , is akin to a Reader 's Digest condensed version of the source material ."]
# ["Though in some ways similar to Catherine Breillat 's Fat Girl , Rain is the far superior film ."]
# Translating to filipino
# ["Though in some ways similar to Catherine Breillat 's Fat Girl , Rain is the far superior film ."]
# ["Though in some ways similar to Catherine Breillat 's Fat Girl , Rain is the far superior film ."]
# ['A solid , psychological action film from Hong Kong .']
# Translating to armenian
# ['A solid , psychological action film from Hong Kong .']
# ['A solid , psychological action film from Hong Kong .']
# ["... a cinematic disaster so inadvertently sidesplitting it 's worth the price of admission for the ridicule factor alone ."]
# Translating to catalan
# ["... a cinematic disaster so inadvertently sidesplitting it 's worth the price of admission for the ridicule factor alone ."]
# ["... a cinematic disaster so inadvertently sidesplitting it 's worth the price of admission for the ridicule factor alone ."]
# ["Those moviegoers who would automatically bypass a hip-hop documentary should give `` Scratch '' a second look ."]
# Translating to filipino
# ["Those moviegoers who would automatically bypass a hip-hop documentary should give `` Scratch '' a second look ."]
# ["Those moviegoers who would automatically bypass a hip-hop documentary should give `` Scratch '' a second look ."]
# ["If you love Motown music , you 'll love this documentary ."]
# Translating to belarusian
# ["If you love Motown music , you 'll love this documentary ."]
# ["If you love Motown music , you 'll love this documentary ."]
# ['New Yorkers always seem to find the oddest places to dwell ...']
# Translating to dutch
# ['New Yorkers always seem to find the oddest places to dwell ...']
# ['New Yorkers always seem to find the oddest places to dwell ...']
# ['Both deserve better .']
# Translating to hebrew
# ['Both deserve better .']
# ['Both deserve better .']
# ['Unfolds with such a wallop of you-are-there immediacy that when the bullets start to fly , your first instinct is to duck .']
# Translating to afrikaans
# ['Unfolds with such a wallop of you-are-there immediacy that when the bullets start to fly , your first instinct is to duck .']
# ['Unfolds with such a wallop of you-are-there immediacy that when the bullets start to fly , your first instinct is to duck .']
# ["Director Kevin Bray excels in breaking glass and marking off the `` Miami Vice '' checklist of power boats , Latin music and dog tracks ."]
# Translating to tajik
# ["Director Kevin Bray excels in breaking glass and marking off the `` Miami Vice '' checklist of power boats , Latin music and dog tracks ."]
# ["Director Kevin Bray excels in breaking glass and marking off the `` Miami Vice '' checklist of power boats , Latin music and dog tracks ."]
# ["It 'll keep you wide awake and ... very tense ."]
# Translating to urdu
# ["It 'll keep you wide awake and ... very tense ."]
# ["It 'll keep you wide awake and ... very tense ."]
# ['The laughs are as rare as snake foo yung .']
# Translating to russian
# ['The laughs are as rare as snake foo yung .']
# ['The laughs are as rare as snake foo yung .']
# ['A confluence of kiddie entertainment , sophisticated wit and symbolic graphic design .']
# Translating to punjabi
# ['A confluence of kiddie entertainment , sophisticated wit and symbolic graphic design .']
# ['A confluence of kiddie entertainment , sophisticated wit and symbolic graphic design .']
# ["Greengrass ( working from Don Mullan 's script ) forgoes the larger socio-political picture of the situation in Northern Ireland in favour of an approach that throws one in the pulsating thick of a truly frightening situation ."]
# Translating to sindhi
# ["Greengrass ( working from Don Mullan 's script ) forgoes the larger socio-political picture of the situation in Northern Ireland in favour of an approach that throws one in the pulsating thick of a truly frightening situation ."]
# ["Greengrass ( working from Don Mullan 's script ) forgoes the larger socio-political picture of the situation in Northern Ireland in favour of an approach that throws one in the pulsating thick of a truly frightening situation ."]
# ['a wonderfully warm human drama that remains vividly in memory long after viewing']
# Translating to latvian
# ['a wonderfully warm human drama that remains vividly in memory long after viewing']
# ['a wonderfully warm human drama that remains vividly in memory long after viewing']
# ["By the time you reach the finale , you 're likely wondering why you 've been watching all this strutting and posturing ."]
# Translating to azerbaijani
# ["By the time you reach the finale , you 're likely wondering why you 've been watching all this strutting and posturing ."]
# ["By the time you reach the finale , you 're likely wondering why you 've been watching all this strutting and posturing ."]
# ['Like being trapped inside a huge video game , where exciting , inane images keep popping past your head and the same illogical things keep happening over and over again .']
# Translating to hindi
# ['Like being trapped inside a huge video game , where exciting , inane images keep popping past your head and the same illogical things keep happening over and over again .']
# ['Like being trapped inside a huge video game , where exciting , inane images keep popping past your head and the same illogical things keep happening over and over again .']
# ['The soundtrack alone is worth the price of admission .']
# Translating to igbo
# ['The soundtrack alone is worth the price of admission .']
# ['The soundtrack alone is worth the price of admission .']
# ["The film 's thoroughly recycled plot and tiresome jokes ... drag the movie down ."]
# Translating to somali
# ["The film 's thoroughly recycled plot and tiresome jokes ... drag the movie down ."]
# ["The film 's thoroughly recycled plot and tiresome jokes ... drag the movie down ."]
# ["Culkin , who 's in virtually every scene , shines as a young man who uses sarcastic lies like a shield ."]
# Translating to hausa
# ["Culkin , who 's in virtually every scene , shines as a young man who uses sarcastic lies like a shield ."]
# ["Culkin , who 's in virtually every scene , shines as a young man who uses sarcastic lies like a shield ."]
# ["If you can keep your eyes open amid all the blood and gore , you 'll see Del Toro has brought unexpected gravity to Blade II ."]
# Translating to hindi
# ["If you can keep your eyes open amid all the blood and gore , you 'll see Del Toro has brought unexpected gravity to Blade II ."]
# ["If you can keep your eyes open amid all the blood and gore , you 'll see Del Toro has brought unexpected gravity to Blade II ."]
# ['Succeeds only because Bullock and Grant were made to share the silver screen .']
# Translating to odia
# ['Succeeds only because Bullock and Grant were made to share the silver screen .']
# ['Succeeds only because Bullock and Grant were made to share the silver screen .']
# ['In a movie full of surprises , the biggest is that Secret Ballot is a comedy , both gentle and biting .']
# Translating to yiddish
# ['In a movie full of surprises , the biggest is that Secret Ballot is a comedy , both gentle and biting .']
# ['In a movie full of surprises , the biggest is that Secret Ballot is a comedy , both gentle and biting .']
# ['The overall result is an intelligent , realistic portrayal of testing boundaries .']
# Translating to korean
# ['The overall result is an intelligent , realistic portrayal of testing boundaries .']
# ['The overall result is an intelligent , realistic portrayal of testing boundaries .']
# ['An awful snooze .']
# Translating to portuguese
# ['An awful snooze .']
# ['An awful snooze .']
# ['Succeeds as a well-made evocation of a subculture .']
# Translating to catalan
# ['Succeeds as a well-made evocation of a subculture .']
# ['Succeeds as a well-made evocation of a subculture .']
# ["The reason to see `` Sade '' lay with the chemistry and complex relationship between the marquis ( Auteil ) and Emilie ( Le Besco ) ."]
# Translating to malay
# ["The reason to see `` Sade '' lay with the chemistry and complex relationship between the marquis ( Auteil ) and Emilie ( Le Besco ) ."]
# ["The reason to see `` Sade '' lay with the chemistry and complex relationship between the marquis ( Auteil ) and Emilie ( Le Besco ) ."]
# ["Stress ` dumb . '"]
# Translating to shona
# ["Stress ` dumb . '"]
# ["Stress ` dumb . '"]
# ['This gorgeous epic is guaranteed to lift the spirits of the whole family .']
# Translating to norwegian
# ['This gorgeous epic is guaranteed to lift the spirits of the whole family .']
# ['This gorgeous epic is guaranteed to lift the spirits of the whole family .']
# ['The rest of the film ... is dudsville .']
# Translating to hausa
# ['The rest of the film ... is dudsville .']
# ['The rest of the film ... is dudsville .']
# ["They were afraid to show this movie to reviewers before its opening , afraid of the bad reviews they thought they 'd earn ."]
# Translating to danish
# ["They were afraid to show this movie to reviewers before its opening , afraid of the bad reviews they thought they 'd earn ."]
# ["They were afraid to show this movie to reviewers before its opening , afraid of the bad reviews they thought they 'd earn ."]
# ['You watch for that sense of openness , the little surprises .']
# Translating to welsh
# ['You watch for that sense of openness , the little surprises .']
# ['You watch for that sense of openness , the little surprises .']
# ['Delivers roughly equal amounts of beautiful movement and inside information .']
# Translating to romanian
# ['Delivers roughly equal amounts of beautiful movement and inside information .']
# ['Delivers roughly equal amounts of beautiful movement and inside information .']
# ['These three films form a remarkably cohesive whole , both visually and thematically , through their consistently sensitive and often exciting treatment of an ignored people .']
# Translating to lithuanian
# ['These three films form a remarkably cohesive whole , both visually and thematically , through their consistently sensitive and often exciting treatment of an ignored people .']
# ['These three films form a remarkably cohesive whole , both visually and thematically , through their consistently sensitive and often exciting treatment of an ignored people .']
# ["It 's a smartly directed , grown-up film of ideas ."]
# Translating to greek
# ["It 's a smartly directed , grown-up film of ideas ."]
# ["It 's a smartly directed , grown-up film of ideas ."]
# ['When the twist endings were actually surprising ?']
# Translating to slovak
# ['When the twist endings were actually surprising ?']
# ['When the twist endings were actually surprising ?']
# ["An invaluable historical document thanks to the filmmaker 's extraordinary access to Massoud , whose charm , cultivation and devotion to his people are readily apparent ."]
# Translating to malay
# ["An invaluable historical document thanks to the filmmaker 's extraordinary access to Massoud , whose charm , cultivation and devotion to his people are readily apparent ."]
# ["An invaluable historical document thanks to the filmmaker 's extraordinary access to Massoud , whose charm , cultivation and devotion to his people are readily apparent ."]
# ['Combines improbable melodrama ( gored bullfighters , comatose ballerinas ) with subtly kinky bedside vigils and sensational denouements , and yet at the end , we are undeniably touched .']
# Translating to english
# ['Combines improbable melodrama ( gored bullfighters , comatose ballerinas ) with subtly kinky bedside vigils and sensational denouements , and yet at the end , we are undeniably touched .']
# ['Combines improbable melodrama ( gored bullfighters , comatose ballerinas ) with subtly kinky bedside vigils and sensational denouements , and yet at the end , we are undeniably touched .']
# ['A poky and pseudo-serious exercise in sham actor workshops and an affected malaise .']
# Translating to spanish
# ['A poky and pseudo-serious exercise in sham actor workshops and an affected malaise .']
# ['A poky and pseudo-serious exercise in sham actor workshops and an affected malaise .']
# ['Caviezel embodies the transformation of his character completely .']
# Translating to odia
# ['Caviezel embodies the transformation of his character completely .']
# ['Caviezel embodies the transformation of his character completely .']
# ['So earnest and well-meaning , and so stocked with talent , that you almost forget the sheer , ponderous awfulness of its script .']
# Translating to cebuano
# ['So earnest and well-meaning , and so stocked with talent , that you almost forget the sheer , ponderous awfulness of its script .']
# ['So earnest and well-meaning , and so stocked with talent , that you almost forget the sheer , ponderous awfulness of its script .']
# ['Although it starts off so bad that you feel like running out screaming , it eventually works its way up to merely bad rather than painfully awful .']
# Translating to swedish
# ['Although it starts off so bad that you feel like running out screaming , it eventually works its way up to merely bad rather than painfully awful .']
# ['Although it starts off so bad that you feel like running out screaming , it eventually works its way up to merely bad rather than painfully awful .']
# ["( Denis ' ) bare-bones narrative more closely resembles an outline for a '70s exploitation picture than the finished product ."]
# Translating to danish
# ["( Denis ' ) bare-bones narrative more closely resembles an outline for a '70s exploitation picture than the finished product ."]
# ["( Denis ' ) bare-bones narrative more closely resembles an outline for a '70s exploitation picture than the finished product ."]
# ['As a randy film about sexy people in gorgeous places being pushed and pulled ( literally and figuratively ) by desire ... ( Sex and Lucía ) makes for an arousing good time .']
# Translating to bulgarian
# ['As a randy film about sexy people in gorgeous places being pushed and pulled ( literally and figuratively ) by desire ... ( Sex and Lucía ) makes for an arousing good time .']
# ['As a randy film about sexy people in gorgeous places being pushed and pulled ( literally and figuratively ) by desire ... ( Sex and Lucía ) makes for an arousing good time .']
# ["In the end , The Weight of Water comes to resemble the kind of soft-core twaddle you 'd expect to see on Showtime 's ` Red Shoe Diaries . '"]
# Translating to catalan
# ["In the end , The Weight of Water comes to resemble the kind of soft-core twaddle you 'd expect to see on Showtime 's ` Red Shoe Diaries . '"]
# ["In the end , The Weight of Water comes to resemble the kind of soft-core twaddle you 'd expect to see on Showtime 's ` Red Shoe Diaries . '"]

# %%
assert len(aug_data_translate['label']) == len(aug_data_translate['text']), "Some error occured. Size Mismatch!"
len(aug_data_translate['text'])
# Out:
# 474

# %%
df_translate = pd.DataFrame.from_dict(aug_data_translate)
df_translate['text'] = df_translate['text'].apply(lambda x: x[0] )
df_translate.head()
# Out:
#    label                                               text
# 0      4  It's always funny, in an irresistible high sch...
# 1      2       Miscalculated, muddy psychological thriller.
# 2      5  LaBute is able to balance Traditional or Moder...
# 3      1  For a depressing story, this is a heart-wrench...
# 4      3  Few of the increasingly attracted events, foll...

# %%
df_translate.to_csv("back_translate_5percent.csv", index=False)
